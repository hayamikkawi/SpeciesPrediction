# %%
import numpy as np
import os
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler, MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, top_k_accuracy_score, auc
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from lightgbm.callback import early_stopping

# %%
TRAIN_LOCS_KEY = 'train_locs'
TRAIN_IDS_KEY = 'train_ids'
TAXON_IDS_KEY = 'taxon_ids'
TAXON_NAME_KEY = 'taxon_names'

TEST_LOCS_KEY = 'test_locs'
TEST_IDS_KEY = 'test_pos_inds'

# %% [markdown]
# Reading the file:

# %%
filepath = os.path.join(os.getcwd(), 'species_train.npz')
data = np.load(filepath, allow_pickle=True)
train_locs = data[TRAIN_LOCS_KEY]
train_ids = data[TRAIN_IDS_KEY]
taxon_ids = data[TAXON_IDS_KEY]
taxon_names = data[TAXON_NAME_KEY]

# %% [markdown]
# Reading the test file:

# %%
test_filepath = os.path.join(os.getcwd(), 'species_test.npz')
test_data = np.load(test_filepath, allow_pickle=True)
test_locs = test_data[TEST_LOCS_KEY]
test_ids = test_data[TEST_IDS_KEY]

# %% [markdown]
# Mapping the taxon ids to taxon latin names:

# %%
species_ids_names = dict(zip(data['taxon_ids'], data['taxon_names']))  # latin names of species

# %% [markdown]
# Create pandas Dataframe from the train data:

# %%
df = pd.DataFrame({
    'latitude': train_locs[:, 0],
    'longitude': train_locs[:, 1], 
    'taxon_id': data[TRAIN_IDS_KEY]
})
df['taxon_name'] = [species_ids_names[id] for id in data[TRAIN_IDS_KEY].astype(int)]
df.head()
# Out:
#     latitude   longitude  taxon_id             taxon_name
# 0 -18.286728  143.481247     31529  Lophognathus gilberti
# 1 -13.099798  130.783646     31529  Lophognathus gilberti
# 2 -13.965274  131.695145     31529  Lophognathus gilberti
# 3 -12.853950  132.800507     31529  Lophognathus gilberti
# 4 -12.196790  134.279327     31529  Lophognathus gilberti

# %% [markdown]
# Create pandas Dataframe from the test data:

# %%
rows = [
    [test_locs[loc_id][0], test_locs[loc_id][1], taxon_id]
    for taxon_id, loc_ids in zip(taxon_ids, test_ids)
    for loc_id in loc_ids
]

# %%
test_df = pd.DataFrame(rows, columns=["latitude", "longitude", "taxon_id"])
test_df['taxon_name'] = [species_ids_names[id] for id in test_df["taxon_id"].astype(int)]
test_df.head()
# Out:
#     latitude   longitude  taxon_id             taxon_name
# 0 -19.884237  126.052979     31529  Lophognathus gilberti
# 1 -20.219316  124.723953     31529  Lophognathus gilberti
# 2 -20.053690  125.386505     31529  Lophognathus gilberti
# 3 -19.973000  126.462440     31529  Lophognathus gilberti
# 4 -19.962839  124.980362     31529  Lophognathus gilberti

# %%
test_df.shape
# Out:
# (1706646, 4)

# %% [markdown]
# Data Cleanining:

# %% [markdown]
# <small>1. Check for missing or invalid coordinates:</small>

# %%
df = df.dropna(subset=['latitude', 'longitude'])
test_df = test_df.dropna(subset=['latitude', 'longitude'])
df = df[(df['latitude'].between(-90, 90)) & (df['longitude'].between(-180, 180))]
test_df = test_df[(test_df['latitude'].between(-90, 90)) & (test_df['longitude'].between(-180, 180))]
df.shape, test_df.shape
# Out:
# ((272037, 4), (1706646, 4))

# %% [markdown]
# <small>2. Remove any duplicates or nearly duplicates (observations that are extremely close):</small>

# %%
df['lat_rounded'] = df['latitude'].round(5)
df['lon_rounded'] = df['longitude'].round(5)
test_df['lat_rounded'] = test_df['latitude'].round(5)
test_df['lon_rounded'] = test_df['longitude'].round(5)

# %%
df = df.drop_duplicates(subset=['lat_rounded', 'lon_rounded', 'taxon_id'])
test_df = test_df.drop_duplicates(subset=['lat_rounded', 'lon_rounded', 'taxon_id'])
df.shape, test_df.shape
# Out:
# ((251822, 6), (1706646, 6))

# %% [markdown]
# <small>4. Validate species IDs: </small>

# %%
df['taxon_id'].isna().sum(), test_df['taxon_id'].isna().sum()
# Out:
# (np.int64(0), np.int64(0))

# %% [markdown]
# <small>5. Only keep birds:</small>

# %% [markdown]
# <small>Note: Only run the next 2 blocks one time as they take a few seconds:</small>

# %%
taxa = pd.read_csv('taxa.csv')
birds = taxa[taxa['class'] == 'Aves']
bird_taxon_ids = set(birds['id'])
len(bird_taxon_ids)
# Out:
# 35102

# %%
df = df[df['taxon_id'].isin(bird_taxon_ids)].copy()
test_df = test_df[test_df['taxon_id'].isin(bird_taxon_ids)].copy()
df.shape, test_df.shape
# Out:
# ((162642, 6), (1323320, 6))

# %% [markdown]
# <small>6. Convert to categorical labels:</small>

# %%
le = LabelEncoder()
le.fit(pd.concat([df['taxon_id'], test_df['taxon_id']]))
df['label'] = le.transform(df['taxon_id'])
test_df['label'] = le.transform(test_df['taxon_id'])

# %% [markdown]
# <small>7. Append the climate data</small>

# %%
import rasterio
import numpy as np
import os

base_dir = os.getcwd()  # assumes folders are in the same directory as this notebook

def load_stack(folder_name):
    folder = os.path.join(base_dir, folder_name)
    files = sorted([os.path.join(folder, f) for f in os.listdir(folder) if f.endswith(".tif")])
    if len(files) != 12:
        raise RuntimeError(f"Expected 12 GeoTIFFs in {folder_name}, found {len(files)}.")
    layers = []
    transform = None
    for f in files:
        with rasterio.open(f) as src:
            layers.append(src.read(1))
            transform = src.transform  # all months share the same transform
    return np.stack(layers), transform  # shape: (12, H, W), and affine transform

tmin, transform = load_stack("wc2.1_2.5m_tmin")
tmax, _         = load_stack("wc2.1_2.5m_tmax")
prec, _         = load_stack("wc2.1_2.5m_prec")

print("Stacks loaded. Shapes:",
      "tmin", tmin.shape, "tmax", tmax.shape, "prec", prec.shape)
print("Transform:", transform)
# Out:
# Stacks loaded. Shapes: tmin (12, 4320, 8640) tmax (12, 4320, 8640) prec (12, 4320, 8640)
# Transform: | 0.04, 0.00,-180.00|
# | 0.00,-0.04, 90.00|
# | 0.00, 0.00, 1.00|

# %%
#Cleaning the data again as the precipitation values are very large, so I'll normalize them
from rasterio.transform import rowcol
import numpy as np

def get_climate_for_points(df, transform, tmin, tmax, prec, lat_col="latitude", lon_col="longitude"):
    # Convert lat/lon → raster indices
    rows, cols = rowcol(transform, df[lon_col].values, df[lat_col].values)
    rows = np.clip(rows, 0, tmin.shape[1]-1)
    cols = np.clip(cols, 0, tmin.shape[2]-1)

    # Helper: clean up weird values (NoData etc.)
    def clean(arr):
        arr = arr.astype(float)
        arr[arr > 1e4] = np.nan  # remove unrealistic large values
        return arr

    tmin = clean(tmin)
    tmax = clean(tmax)
    prec = clean(prec)

    # Extract values and average across 12 months safely
    tmin_mean = np.nanmean(tmin[:, rows, cols], axis=0)
    tmax_mean = np.nanmean(tmax[:, rows, cols], axis=0)
    prec_mean = np.nanmean(prec[:, rows, cols], axis=0)

    return tmin_mean, tmax_mean, prec_mean

# %%
tmin_avg, tmax_avg, prec_avg = get_climate_for_points(df, transform, tmin, tmax, prec)

# %%
test_tmin_avg, test_tmax_avg, test_prec_avg = get_climate_for_points(test_df, transform, tmin, tmax, prec)

# %%
df["Tmin_avg"] = tmin_avg
df["Tmax_avg"] = tmax_avg
df["Prec_avg"] = prec_avg

df[["latitude","longitude","Tmin_avg","Tmax_avg","Prec_avg"]].head()
# Out:
#      latitude   longitude   Tmin_avg   Tmax_avg    Prec_avg
# 53  21.086105  -86.852867  20.967000  31.436000  103.416667
# 54  19.186003  -96.199600  19.327333  31.831333  117.833333
# 55  17.538877  -89.113724  19.496333  30.576333  125.583333
# 56  20.648556 -105.220955  19.674123  31.835527   87.750000
# 57  18.409698  -95.096657  20.515000  29.086000  156.750000

# %%
test_df["Tmin_avg"] = test_tmin_avg
test_df["Tmax_avg"] = test_tmax_avg
test_df["Prec_avg"] = test_prec_avg

test_df[["latitude","longitude","Tmin_avg","Tmax_avg","Prec_avg"]].head()
# Out:
#       latitude  longitude      Tmin_avg      Tmax_avg      Prec_avg
# 784  19.289352 -89.842888  1.885033e+01  3.272100e+01     91.750000
# 785  20.777590 -88.534241  1.882467e+01  3.272433e+01    103.833333
# 786  21.513868 -86.804565  2.165833e+01  3.071667e+01    100.250000
# 787  18.710384 -94.898964 -3.400000e+38 -3.400000e+38 -32768.000000
# 788  21.509193 -88.522995  1.973447e+01  3.149773e+01     73.250000

# %%
out_path = "bird_species_rerun_with_averaged_climate.csv"
df.to_csv(out_path, index=False)
out_path, df.shape
# Out:
# ('bird_species_rerun_with_averaged_climate.csv', (162642, 10))

# %%
out_path = "test_bird_species_rerun_with_averaged_climate.csv"
test_df.to_csv(out_path, index=False)
out_path, test_df.shape
# Out:
# ('test_bird_species_rerun_with_averaged_climate.csv', (1323320, 10))

# %%
df = pd.read_csv('bird_species_rerun_with_averaged_climate.csv')

# %%
test_df = pd.read_csv('test_bird_species_rerun_with_averaged_climate.csv')

# %% [markdown]
# <small>8. Clean the climate data</small>

# %%
df['Tmin_avg'] = df['Tmin_avg'].mask(df['Tmin_avg'] < -1e+30, np.nan)
df['Tmax_avg'] = df['Tmax_avg'].mask(df['Tmax_avg'] < -1e+30, np.nan)
df['Prec_avg'] = df['Prec_avg'].mask(df['Prec_avg'] < 0, np.nan)
print(f"Shape with nan data: {df.shape}")
df = df.dropna(subset=['Tmin_avg', 'Tmax_avg', 'Prec_avg'])
print(f"Shape without nan data: {df.shape}")
# Out:
# Shape with nan data: (162642, 10)
# Shape without nan data: (161432, 10)

# %%
len(test_df)
# Out:
# 1323320

# %%
test_df['Tmin_avg'] = test_df['Tmin_avg'].mask(test_df['Tmin_avg'] < -1e+30, np.nan)
test_df['Tmax_avg'] = test_df['Tmax_avg'].mask(test_df['Tmax_avg'] < -1e+30, np.nan)
test_df['Prec_avg'] = test_df['Prec_avg'].mask(test_df['Prec_avg'] < 0, np.nan)
print(f"Shape with nan data: {test_df.shape}")
test_df = test_df.dropna(subset=['Tmin_avg', 'Tmax_avg', 'Prec_avg'])
print(f"Shape without nan data: {test_df.shape}")
# Out:
# Shape with nan data: (1323320, 10)
# Shape without nan data: (928354, 10)

# %% [markdown]
# <small>Note: mention in the report that we lost a lot of data because of removing NaN temperature, in the ociens mainly.</small>

# %%
(df['Tmax_avg'] < df['Tmin_avg']).sum(), (test_df['Tmax_avg'] < test_df['Tmin_avg']).sum()
# Out:
# (np.int64(0), np.int64(0))

# %% [markdown]
# <small>Add sin feature to capture circularity</small>

# %%
df['lat_sin'] = np.sin(np.deg2rad(df['latitude']))
df['lat_cos'] = np.cos(np.deg2rad(df['latitude']))
df['lon_sin'] = np.sin(np.deg2rad(df['longitude']))
df['lon_cos'] = np.cos(np.deg2rad(df['longitude']))

# %%
test_df['lat_sin'] = np.sin(np.deg2rad(test_df['latitude']))
test_df['lat_cos'] = np.cos(np.deg2rad(test_df['latitude']))
test_df['lon_sin'] = np.sin(np.deg2rad(test_df['longitude']))
test_df['lon_cos'] = np.cos(np.deg2rad(test_df['longitude']))

# %%
df.shape, test_df.shape
# Out:
# ((161432, 14), (928354, 14))

# %% [markdown]
# <small>9. Split the data to x and y and normalize the climate features</small>

# %%
X_data = df.drop(columns=['taxon_id', 'taxon_name', 'lat_rounded', 'lon_rounded', 'label'])
y_data = df['label']
climate_features = ['Tmin_avg', 'Tmax_avg', 'Prec_avg']
non_scaled_features = ['latitude', 'longitude']
# scale climate 
scaler = StandardScaler()
scaler.fit(X_data[climate_features])
X_scaled = X_data.copy()
X_scaled[climate_features] = scaler.transform(X_data[climate_features])
X_scaled.describe()
# Out:
#             latitude      longitude      Tmin_avg      Tmax_avg      Prec_avg  \
# count  161432.000000  161432.000000  1.614320e+05  1.614320e+05  1.614320e+05
# mean       14.827329      -8.036515  1.929617e-16  3.014146e-16  1.690175e-17
# std        31.900029      95.705462  1.000003e+00  1.000003e+00  1.000003e+00
# min       -75.284950    -178.060320 -6.699036e+00 -6.690300e+00 -1.635481e+00
# 25%       -21.050622     -96.105056 -6.488781e-01 -7.633616e-01 -6.553056e-01
# 50%        26.165924     -43.440056  1.560563e-02  1.265317e-01 -1.806941e-01
# 75%        40.959681      75.385002  6.814487e-01  7.350146e-01  3.936545e-01
# max        72.515430     178.827590  2.250907e+00  2.213666e+00  1.319785e+01
#
#              lat_sin        lat_cos        lon_sin        lon_cos
# count  161432.000000  161432.000000  161432.000000  161432.000000
# mean        0.230808       0.820155      -0.203034       0.042523
# std         0.509097       0.122050       0.770315       0.602984
# min        -0.967201       0.254012      -1.000000      -0.999791
# 25%        -0.359193       0.747490      -0.968077      -0.459039
# 50%         0.440972       0.831109      -0.673665       0.067571
# 75%         0.655528       0.914683       0.524633       0.545473
# max         0.953798       1.000000       1.000000       1.000000

# %%
X_test = test_df.drop(columns=['taxon_id', 'taxon_name', 'lat_rounded', 'lon_rounded', 'label'])
y_test = test_df['label']
climate_features = ['Tmin_avg', 'Tmax_avg', 'Prec_avg']
non_scaled_features = ['latitude', 'longitude']
# scale climate 
X_test_scaled = X_test.copy()
X_test_scaled[climate_features] = scaler.transform(X_test[climate_features])
X_test_scaled.describe()
# Out:
#             latitude      longitude       Tmin_avg       Tmax_avg  \
# count  928354.000000  928354.000000  928354.000000  928354.000000
# mean       13.171677      13.497898       0.183610       0.289493
# std        29.127638      77.380268       1.432959       1.412140
# min       -85.600830    -179.933670      -6.928313      -7.189774
# 25%       -12.422070     -59.177242      -0.792492      -0.690674
# 50%        11.103984      23.309443       0.622043       0.861617
# 75%        38.710465      74.511734       1.357427       1.342591
# max        82.845260     179.994780       2.595104       2.364347
#
#             Prec_avg        lat_sin        lat_cos        lon_sin  \
# count  928354.000000  928354.000000  928354.000000  928354.000000
# mean       -0.008040       0.198286       0.853137       0.094081
# std         1.242831       0.455790       0.158418       0.745243
# min        -1.635481      -0.997054       0.076705      -1.000000
# 25%        -0.923564      -0.215112       0.773541      -0.837545
# 50%        -0.350935       0.192590       0.913240       0.389406
# 75%         0.594849       0.625385       0.979165       0.720192
# max        12.102457       0.992213       1.000000       1.000000
#
#              lon_cos
# count  928354.000000
# mean        0.314364
# std         0.580464
# min        -1.000000
# 25%        -0.177202
# 50%         0.445380
# 75%         0.853618
# max         1.000000

# %% [markdown]
# <small>9. Split to train and validation sets</small>

# %%
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y_data,
                                                  test_size=0.2,
                                                  random_state=42, 
                                                  stratify=y_data)

X_train.to_csv('X_train.csv', index=False)
X_val.to_csv('X_val.csv', index=False)
y_train.to_csv('y_train.csv', index=False)
y_val.to_csv('y_val.csv', index=False)

# %% [markdown]
# Exploratory Data Analysis:

# %%
# Hajer

# %% [markdown]
# Models:

# %% [markdown]
# <small>Model 1: LightGBM<br> This model depends on decision tree and has hyperparameters</small>

# %%
# Model 1 (a): LightGBM with probability distribution output
# Note to Maya: This is not very important model, Model 1 (b) is more important
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test_scaled, label=y_test)
boosting_types = ['gbdt']
num_leaves = [31]
max_depths = [-1]
for boosting_type in boosting_types: 
    for num_leaf in num_leaves: 
        for max_depth in max_depths: 
            params = {
                'objective': 'multiclass',
                'num_class': 285,
                'learning_rate': 0.05,
                'metric': 'multi_logloss',
                'boosting_type': "gbdt",
                'max_depth': 30, 
                'num_leaves': 31, 
                'lambda_l1': 0.5,
                'lambda_l2': 1.0, 
                'is_unbalance': True
            }
            clf = lgb.train(
                params,
                train_data,
                valid_sets=[test_data],
                num_boost_round=2000,
                callbacks= [early_stopping(stopping_rounds=100)]
            )
            y_pred_prob = clf.predict(X_test_scaled, num_iteration=clf.best_iteration)
            y_pred = y_pred_prob.argmax(axis=1)
            print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
# Note to Maya: If this doesn't work just comment it
print(f1_score(y_test, y_pred, average='macro'))
print("Top-5 acc", top_k_accuracy_score(y_test, y_pred_prob, k=5, labels=list(set(y_train))))
print("Top-7 acc", top_k_accuracy_score(y_test, y_pred_prob, k=7, labels=list(set(y_train))))
print("Top-10 acc", top_k_accuracy_score(y_test, y_pred_prob, k=10, labels=list(set(y_train))))

# %%
# Model 1 (b): LightGBM with vector binary output

# %%
train_df = X_train.copy()
train_df['label'] = y_train
grouped_train = (
    train_df.groupby(list(X_train.columns))['label']
    .apply(list)
    .reset_index(name='labels')
)

# %%
train_df = X_val.copy()
train_df['label'] = y_val
grouped_val = (
    train_df.groupby(list(X_val.columns))['label']
    .apply(list)
    .reset_index(name='labels')
)

# %%
grouped_train.head()
# Out:
#     latitude   longitude  Tmin_avg  Tmax_avg  Prec_avg   lat_sin   lat_cos  \
# 0 -75.284950 -102.746760 -3.808437 -4.360072 -0.285590 -0.967201  0.254012
# 1 -75.250980   -0.071389 -6.699036 -6.690300 -1.494474 -0.967050  0.254585
# 2 -67.566444  -68.129295 -2.445172 -3.109188 -0.971713 -0.924323  0.381612
# 3 -65.889150  -66.195350 -2.298080 -3.007162 -0.418000 -0.912757  0.408503
# 4 -65.063310  -64.039406 -2.333057 -3.051751 -0.096433 -0.906774  0.421617
#
#     lon_sin   lon_cos labels
# 0 -0.975355 -0.220642  [202]
# 1 -0.001246  0.999999  [202]
# 2 -0.928027  0.372513  [202]
# 3 -0.914927  0.403620  [202]
# 4 -0.899095  0.437753  [202]

# %%
grouped_train.shape
# Out:
# (122166, 10)

# %%
grouped_val.head()
# Out:
#     latitude  longitude  Tmin_avg  Tmax_avg  Prec_avg   lat_sin   lat_cos  \
# 0 -65.075900 -63.996357 -2.241169 -2.978719 -0.092994 -0.906867  0.421417
# 1 -64.876114 -62.542420 -2.561603 -3.333969 -0.428318 -0.905392  0.424577
# 2 -64.823880 -62.856915 -2.273834 -3.036636 -0.170376 -0.905004  0.425402
# 3 -64.696686 -62.739140 -2.480519 -3.265628 -0.301067 -0.904058  0.427410
# 4 -64.689300 -61.967083 -2.590112 -3.407331 -0.591680 -0.904003  0.427527
#
#     lon_sin   lon_cos labels
# 0 -0.898766  0.438428  [202]
# 1 -0.887352  0.461092  [202]
# 2 -0.889870  0.456214  [202]
# 3 -0.888930  0.458042   [27]
# 4 -0.882678  0.469979  [202]

# %%
grouped_val.shape
# Out:
# (31667, 10)

# %%
test_df = X_test_scaled.copy()
test_df['label'] = y_test
grouped_test = (
    test_df.groupby(list(X_test.columns))['label']
    .apply(list)
    .reset_index(name='labels')
)
grouped_test.shape
# Out:
# (75432, 10)

# %%
grouped_test[290: 300]
# Out:
#       latitude   longitude  Tmin_avg  Tmax_avg  Prec_avg   lat_sin   lat_cos  \
# 290 -69.531660   33.893047 -4.649422 -4.999933 -1.112721 -0.936866  0.349690
# 291 -69.509710  -67.743520 -3.580448 -3.979311 -1.286401 -0.936732  0.350049
# 292 -69.483080  -69.881020 -3.970080 -4.315951 -1.135076 -0.936569  0.350484
# 293 -69.260826   68.967660 -3.847977 -4.427454 -1.135076 -0.935202  0.354114
# 294 -69.244560  -70.887570 -4.460877 -4.716619 -1.083488 -0.935102  0.354380
# 295 -69.243250  -62.398620 -3.433829 -4.037443 -1.315635 -0.935093  0.354401
# 296 -69.226600  158.234100 -3.536519 -4.371476 -1.252009 -0.934990  0.354673
# 297 -69.208015   77.470505 -4.085506 -4.695692 -1.264046 -0.934875  0.354976
# 298 -69.194860   33.190598 -4.364435 -4.757293 -1.019862 -0.934794  0.355191
# 299 -69.048870  -63.485900 -3.532068 -4.056594 -1.286401 -0.933886  0.357572
#
#       lon_sin   lon_cos         labels
# 290  0.557644  0.830080       [27, 28]
# 291 -0.925498  0.378753       [27, 28]
# 292 -0.938980  0.343971       [27, 28]
# 293  0.933378  0.358895  [202, 27, 28]
# 294 -0.944878  0.327423           [27]
# 295 -0.886192  0.463317  [202, 27, 28]
# 296  0.370815 -0.928707  [202, 27, 28]
# 297  0.976184  0.216942  [202, 27, 28]
# 298  0.547426  0.836854       [27, 28]
# 299 -0.894825  0.446418  [202, 27, 28]

# %%
mlb = MultiLabelBinarizer(classes=range(285))
Y_train = mlb.fit_transform(grouped_train['labels'])
Y_test = mlb.transform(grouped_test['labels'])
X_train_ready = grouped_train.drop(columns=['labels'])
X_test_ready = grouped_test.drop(columns=['labels'])

# %%
Y_val = mlb.transform(grouped_val['labels'])
X_val_ready = grouped_val.drop(columns=['labels'])

# %%
X_train_ready_no_cos = X_train_ready.drop(columns=['lat_sin', 'lat_cos', 'lon_sin', 'lon_cos'])
X_test_ready_no_cos = X_test_ready.drop(columns=['lat_sin', 'lat_cos', 'lon_sin', 'lon_cos'])

X_train_ready.head()
# Out:
#     latitude   longitude  Tmin_avg  Tmax_avg  Prec_avg   lat_sin   lat_cos  \
# 0 -75.284950 -102.746760 -3.808437 -4.360072 -0.285590 -0.967201  0.254012
# 1 -75.250980   -0.071389 -6.699036 -6.690300 -1.494474 -0.967050  0.254585
# 2 -67.566444  -68.129295 -2.445172 -3.109188 -0.971713 -0.924323  0.381612
# 3 -65.889150  -66.195350 -2.298080 -3.007162 -0.418000 -0.912757  0.408503
# 4 -65.063310  -64.039406 -2.333057 -3.051751 -0.096433 -0.906774  0.421617
#
#     lon_sin   lon_cos
# 0 -0.975355 -0.220642
# 1 -0.001246  0.999999
# 2 -0.928027  0.372513
# 3 -0.914927  0.403620
# 4 -0.899095  0.437753

# %%
X_val_ready_no_cos = X_val_ready.drop(columns=['lat_sin', 'lat_cos', 'lon_sin', 'lon_cos'])

# %%
from sklearn.multioutput import MultiOutputClassifier

base_model = lgb.LGBMClassifier(
    objective='binary',     # because each label is a binary classification
    n_estimators=200,
    learning_rate=0.05,
    num_leaves=31,
    n_jobs=-1
)
multi_model = MultiOutputClassifier(base_model)
# Y_pred_proba = np.column_stack([p[:, 1] for p in Y_pred_proba])  # take probability of class 1 for each label
# Y_pred = (Y_pred_proba > 0.5).astype(int)
# Out:
# [LightGBM] [Info] Number of positive: 187, number of negative: 121979
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001194 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001531 -> initscore=-6.480496
# [LightGBM] [Info] Start training from score -6.480496
# [LightGBM] [Info] Number of positive: 283, number of negative: 121883
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002317 -> initscore=-6.065370
# [LightGBM] [Info] Start training from score -6.065370
# [LightGBM] [Info] Number of positive: 906, number of negative: 121260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001232 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.007416 -> initscore=-4.896653
# [LightGBM] [Info] Start training from score -4.896653
# [LightGBM] [Info] Number of positive: 53, number of negative: 122113
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000434 -> initscore=-7.742410
# [LightGBM] [Info] Start training from score -7.742410
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 40, number of negative: 122126
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001178 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000327 -> initscore=-8.023929
# [LightGBM] [Info] Start training from score -8.023929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 62, number of negative: 122104
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000508 -> initscore=-7.585494
# [LightGBM] [Info] Start training from score -7.585494
# [LightGBM] [Info] Number of positive: 1500, number of negative: 120666
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001168 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.012278 -> initscore=-4.387561
# [LightGBM] [Info] Start training from score -4.387561
# [LightGBM] [Info] Number of positive: 424, number of negative: 121742
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001192 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003471 -> initscore=-5.659926
# [LightGBM] [Info] Start training from score -5.659926
# [LightGBM] [Info] Number of positive: 52, number of negative: 122114
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000426 -> initscore=-7.761467
# [LightGBM] [Info] Start training from score -7.761467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 42, number of negative: 122124
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000344 -> initscore=-7.975123
# [LightGBM] [Info] Start training from score -7.975123
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 256, number of negative: 121910
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002096 -> initscore=-6.165861
# [LightGBM] [Info] Start training from score -6.165861
# [LightGBM] [Info] Number of positive: 272, number of negative: 121894
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002226 -> initscore=-6.105105
# [LightGBM] [Info] Start training from score -6.105105
# [LightGBM] [Info] Number of positive: 346, number of negative: 121820
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002832 -> initscore=-5.863861
# [LightGBM] [Info] Start training from score -5.863861
# [LightGBM] [Info] Number of positive: 549, number of negative: 121617
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.004494 -> initscore=-5.400534
# [LightGBM] [Info] Start training from score -5.400534
# [LightGBM] [Info] Number of positive: 173, number of negative: 121993
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001416 -> initscore=-6.558427
# [LightGBM] [Info] Start training from score -6.558427
# [LightGBM] [Info] Number of positive: 169, number of negative: 121997
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001383 -> initscore=-6.581853
# [LightGBM] [Info] Start training from score -6.581853
# [LightGBM] [Info] Number of positive: 1179, number of negative: 120987
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001181 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.009651 -> initscore=-4.631016
# [LightGBM] [Info] Start training from score -4.631016
# [LightGBM] [Info] Number of positive: 55, number of negative: 122111
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001169 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000450 -> initscore=-7.705353
# [LightGBM] [Info] Start training from score -7.705353
# [LightGBM] [Info] Number of positive: 42, number of negative: 122124
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000344 -> initscore=-7.975123
# [LightGBM] [Info] Start training from score -7.975123
# [LightGBM] [Info] Number of positive: 398, number of negative: 121768
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001185 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003258 -> initscore=-5.723421
# [LightGBM] [Info] Start training from score -5.723421
# [LightGBM] [Info] Number of positive: 974, number of negative: 121192
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.007973 -> initscore=-4.823720
# [LightGBM] [Info] Start training from score -4.823720
# [LightGBM] [Info] Number of positive: 44, number of negative: 122122
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000360 -> initscore=-7.928586
# [LightGBM] [Info] Start training from score -7.928586
# [LightGBM] [Info] Number of positive: 1331, number of negative: 120835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.010895 -> initscore=-4.508495
# [LightGBM] [Info] Start training from score -4.508495
# [LightGBM] [Info] Number of positive: 90, number of negative: 122076
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001192 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000737 -> initscore=-7.212589
# [LightGBM] [Info] Start training from score -7.212589
# [LightGBM] [Info] Number of positive: 706, number of negative: 121460
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.005779 -> initscore=-5.147725
# [LightGBM] [Info] Start training from score -5.147725
# [LightGBM] [Info] Number of positive: 510, number of negative: 121656
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001163 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.004175 -> initscore=-5.474542
# [LightGBM] [Info] Start training from score -5.474542
# [LightGBM] [Info] Number of positive: 226, number of negative: 121940
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001850 -> initscore=-6.290749
# [LightGBM] [Info] Start training from score -6.290749
# [LightGBM] [Info] Number of positive: 38, number of negative: 122128
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001214 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000311 -> initscore=-8.075239
# [LightGBM] [Info] Start training from score -8.075239
# [LightGBM] [Info] Number of positive: 34, number of negative: 122132
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000278 -> initscore=-8.186497
# [LightGBM] [Info] Start training from score -8.186497
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 1552, number of negative: 120614
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.012704 -> initscore=-4.353051
# [LightGBM] [Info] Start training from score -4.353051
# [LightGBM] [Info] Number of positive: 37, number of negative: 122129
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001174 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000303 -> initscore=-8.101915
# [LightGBM] [Info] Start training from score -8.101915
# [LightGBM] [Info] Number of positive: 1490, number of negative: 120676
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001178 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.012197 -> initscore=-4.394333
# [LightGBM] [Info] Start training from score -4.394333
# [LightGBM] [Info] Number of positive: 188, number of negative: 121978
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001539 -> initscore=-6.475154
# [LightGBM] [Info] Start training from score -6.475154
# [LightGBM] [Info] Number of positive: 460, number of negative: 121706
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001171 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003765 -> initscore=-5.578137
# [LightGBM] [Info] Start training from score -5.578137
# [LightGBM] [Info] Number of positive: 368, number of negative: 121798
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003012 -> initscore=-5.802036
# [LightGBM] [Info] Start training from score -5.802036
# [LightGBM] [Info] Number of positive: 37, number of negative: 122129
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000303 -> initscore=-8.101915
# [LightGBM] [Info] Start training from score -8.101915
# [LightGBM] [Info] Number of positive: 1565, number of negative: 120601
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.012810 -> initscore=-4.344602
# [LightGBM] [Info] Start training from score -4.344602
# [LightGBM] [Info] Number of positive: 91, number of negative: 122075
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001188 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000745 -> initscore=-7.201531
# [LightGBM] [Info] Start training from score -7.201531
# [LightGBM] [Info] Number of positive: 1533, number of negative: 120633
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.012548 -> initscore=-4.365526
# [LightGBM] [Info] Start training from score -4.365526
# [LightGBM] [Info] Number of positive: 1556, number of negative: 120610
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001163 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.012737 -> initscore=-4.350444
# [LightGBM] [Info] Start training from score -4.350444
# [LightGBM] [Info] Number of positive: 167, number of negative: 121999
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001367 -> initscore=-6.593774
# [LightGBM] [Info] Start training from score -6.593774
# [LightGBM] [Info] Number of positive: 114, number of negative: 122052
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000933 -> initscore=-6.976004
# [LightGBM] [Info] Start training from score -6.976004
# [LightGBM] [Info] Number of positive: 122, number of negative: 122044
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001260 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000999 -> initscore=-6.908116
# [LightGBM] [Info] Start training from score -6.908116
# [LightGBM] [Info] Number of positive: 765, number of negative: 121401
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001172 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.006262 -> initscore=-5.066979
# [LightGBM] [Info] Start training from score -5.066979
# [LightGBM] [Info] Number of positive: 779, number of negative: 121387
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001165 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.006377 -> initscore=-5.048728
# [LightGBM] [Info] Start training from score -5.048728
# [LightGBM] [Info] Number of positive: 262, number of negative: 121904
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002145 -> initscore=-6.142645
# [LightGBM] [Info] Start training from score -6.142645
# [LightGBM] [Info] Number of positive: 170, number of negative: 121996
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001171 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001392 -> initscore=-6.575945
# [LightGBM] [Info] Start training from score -6.575945
# [LightGBM] [Info] Number of positive: 200, number of negative: 121966
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001169 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001637 -> initscore=-6.413180
# [LightGBM] [Info] Start training from score -6.413180
# [LightGBM] [Info] Number of positive: 98, number of negative: 122068
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000802 -> initscore=-7.127366
# [LightGBM] [Info] Start training from score -7.127366
# [LightGBM] [Info] Number of positive: 526, number of negative: 121640
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.004306 -> initscore=-5.443520
# [LightGBM] [Info] Start training from score -5.443520
# [LightGBM] [Info] Number of positive: 229, number of negative: 121937
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001187 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001874 -> initscore=-6.277538
# [LightGBM] [Info] Start training from score -6.277538
# [LightGBM] [Info] Number of positive: 93, number of negative: 122073
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001236 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000761 -> initscore=-7.179775
# [LightGBM] [Info] Start training from score -7.179775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 66, number of negative: 122100
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000540 -> initscore=-7.522941
# [LightGBM] [Info] Start training from score -7.522941
# [LightGBM] [Info] Number of positive: 44, number of negative: 122122
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001203 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000360 -> initscore=-7.928586
# [LightGBM] [Info] Start training from score -7.928586
# [LightGBM] [Info] Number of positive: 281, number of negative: 121885
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002300 -> initscore=-6.072479
# [LightGBM] [Info] Start training from score -6.072479
# [LightGBM] [Info] Number of positive: 242, number of negative: 121924
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001981 -> initscore=-6.222215
# [LightGBM] [Info] Start training from score -6.222215
# [LightGBM] [Info] Number of positive: 49, number of negative: 122117
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001168 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000401 -> initscore=-7.820915
# [LightGBM] [Info] Start training from score -7.820915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 36, number of negative: 122130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000295 -> initscore=-8.129322
# [LightGBM] [Info] Start training from score -8.129322
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 110, number of negative: 122056
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001269 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000900 -> initscore=-7.011755
# [LightGBM] [Info] Start training from score -7.011755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 1361, number of negative: 120805
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001222 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.011141 -> initscore=-4.485958
# [LightGBM] [Info] Start training from score -4.485958
# [LightGBM] [Info] Number of positive: 108, number of negative: 122058
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001147 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000884 -> initscore=-7.030120
# [LightGBM] [Info] Start training from score -7.030120
# [LightGBM] [Info] Number of positive: 665, number of negative: 121501
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001272 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.005443 -> initscore=-5.207891
# [LightGBM] [Info] Start training from score -5.207891
# [LightGBM] [Info] Number of positive: 281, number of negative: 121885
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001165 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002300 -> initscore=-6.072479
# [LightGBM] [Info] Start training from score -6.072479
# [LightGBM] [Info] Number of positive: 253, number of negative: 121913
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001177 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002071 -> initscore=-6.177673
# [LightGBM] [Info] Start training from score -6.177673
# [LightGBM] [Info] Number of positive: 152, number of negative: 122014
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001174 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001244 -> initscore=-6.688011
# [LightGBM] [Info] Start training from score -6.688011
# [LightGBM] [Info] Number of positive: 456, number of negative: 121710
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001172 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003733 -> initscore=-5.586904
# [LightGBM] [Info] Start training from score -5.586904
# [LightGBM] [Info] Number of positive: 1555, number of negative: 120611
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.012729 -> initscore=-4.351095
# [LightGBM] [Info] Start training from score -4.351095
# [LightGBM] [Info] Number of positive: 1383, number of negative: 120783
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001280 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.011321 -> initscore=-4.469740
# [LightGBM] [Info] Start training from score -4.469740
# [LightGBM] [Info] Number of positive: 43, number of negative: 122123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001174 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000352 -> initscore=-7.951584
# [LightGBM] [Info] Start training from score -7.951584
# [LightGBM] [Info] Number of positive: 356, number of negative: 121810
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002914 -> initscore=-5.835287
# [LightGBM] [Info] Start training from score -5.835287
# [LightGBM] [Info] Number of positive: 311, number of negative: 121855
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001179 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002546 -> initscore=-5.970794
# [LightGBM] [Info] Start training from score -5.970794
# [LightGBM] [Info] Number of positive: 279, number of negative: 121887
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001209 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002284 -> initscore=-6.079638
# [LightGBM] [Info] Start training from score -6.079638
# [LightGBM] [Info] Number of positive: 58, number of negative: 122108
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001250 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000475 -> initscore=-7.652218
# [LightGBM] [Info] Start training from score -7.652218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 70, number of negative: 122096
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001169 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000573 -> initscore=-7.464068
# [LightGBM] [Info] Start training from score -7.464068
# [LightGBM] [Info] Number of positive: 1187, number of negative: 120979
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.009716 -> initscore=-4.624188
# [LightGBM] [Info] Start training from score -4.624188
# [LightGBM] [Info] Number of positive: 40, number of negative: 122126
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000327 -> initscore=-8.023929
# [LightGBM] [Info] Start training from score -8.023929
# [LightGBM] [Info] Number of positive: 140, number of negative: 122026
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001188 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001146 -> initscore=-6.770347
# [LightGBM] [Info] Start training from score -6.770347
# [LightGBM] [Info] Number of positive: 209, number of negative: 121957
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001711 -> initscore=-6.369090
# [LightGBM] [Info] Start training from score -6.369090
# [LightGBM] [Info] Number of positive: 42, number of negative: 122124
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001180 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000344 -> initscore=-7.975123
# [LightGBM] [Info] Start training from score -7.975123
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 111, number of negative: 122055
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000909 -> initscore=-7.002697
# [LightGBM] [Info] Start training from score -7.002697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Info] Start training from score -5.122401
# [LightGBM] [Info] Number of positive: 1570, number of negative: 120596
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.012851 -> initscore=-4.341370
# [LightGBM] [Info] Start training from score -4.341370
# [LightGBM] [Info] Number of positive: 272, number of negative: 121894
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001169 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002226 -> initscore=-6.105105
# [LightGBM] [Info] Start training from score -6.105105
# [LightGBM] [Info] Number of positive: 121, number of negative: 122045
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000990 -> initscore=-6.916355
# [LightGBM] [Info] Start training from score -6.916355
# [LightGBM] [Info] Number of positive: 45, number of negative: 122121
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000368 -> initscore=-7.906105
# [LightGBM] [Info] Start training from score -7.906105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 528, number of negative: 121638
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.004322 -> initscore=-5.439708
# [LightGBM] [Info] Start training from score -5.439708
# [LightGBM] [Info] Number of positive: 300, number of negative: 121866
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002456 -> initscore=-6.006895
# [LightGBM] [Info] Start training from score -6.006895
# [LightGBM] [Info] Number of positive: 138, number of negative: 122028
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001163 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001130 -> initscore=-6.784752
# [LightGBM] [Info] Start training from score -6.784752
# [LightGBM] [Info] Number of positive: 357, number of negative: 121809
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002922 -> initscore=-5.832474
# [LightGBM] [Info] Start training from score -5.832474
# [LightGBM] [Info] Number of positive: 95, number of negative: 122071
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001203 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000778 -> initscore=-7.158481
# [LightGBM] [Info] Start training from score -7.158481
# [LightGBM] [Info] Number of positive: 310, number of negative: 121856
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001183 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002538 -> initscore=-5.974023
# [LightGBM] [Info] Start training from score -5.974023
# [LightGBM] [Info] Number of positive: 522, number of negative: 121644
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.004273 -> initscore=-5.451186
# [LightGBM] [Info] Start training from score -5.451186
# [LightGBM] [Info] Number of positive: 166, number of negative: 122000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001210 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001359 -> initscore=-6.599789
# [LightGBM] [Info] Start training from score -6.599789
# [LightGBM] [Info] Number of positive: 94, number of negative: 122072
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001169 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000769 -> initscore=-7.169072
# [LightGBM] [Info] Start training from score -7.169072
# [LightGBM] [Info] Number of positive: 202, number of negative: 121964
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001653 -> initscore=-6.403214
# [LightGBM] [Info] Start training from score -6.403214
# [LightGBM] [Info] Number of positive: 195, number of negative: 121971
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001596 -> initscore=-6.438539
# [LightGBM] [Info] Start training from score -6.438539
# [LightGBM] [Info] Number of positive: 574, number of negative: 121592
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001180 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.004699 -> initscore=-5.355797
# [LightGBM] [Info] Start training from score -5.355797
# [LightGBM] [Info] Number of positive: 218, number of negative: 121948
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001319 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001784 -> initscore=-6.326855
# [LightGBM] [Info] Start training from score -6.326855
# [LightGBM] [Info] Number of positive: 162, number of negative: 122004
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001326 -> initscore=-6.624213
# [LightGBM] [Info] Start training from score -6.624213
# [LightGBM] [Info] Number of positive: 82, number of negative: 122084
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000671 -> initscore=-7.305745
# [LightGBM] [Info] Start training from score -7.305745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 44, number of negative: 122122
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001221 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000360 -> initscore=-7.928586
# [LightGBM] [Info] Start training from score -7.928586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 296, number of negative: 121870
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001259 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002423 -> initscore=-6.020351
# [LightGBM] [Info] Start training from score -6.020351
# [LightGBM] [Info] Number of positive: 453, number of negative: 121713
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003708 -> initscore=-5.593529
# [LightGBM] [Info] Start training from score -5.593529
# [LightGBM] [Info] Number of positive: 54, number of negative: 122112
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001300 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000442 -> initscore=-7.723710
# [LightGBM] [Info] Start training from score -7.723710
# [LightGBM] [Info] Number of positive: 50, number of negative: 122116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000409 -> initscore=-7.800704
# [LightGBM] [Info] Start training from score -7.800704
# [LightGBM] [Info] Number of positive: 36, number of negative: 122130
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000295 -> initscore=-8.129322
# [LightGBM] [Info] Start training from score -8.129322
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 114, number of negative: 122052
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000933 -> initscore=-6.976004
# [LightGBM] [Info] Start training from score -6.976004
# [LightGBM] [Info] Number of positive: 169, number of negative: 121997
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001169 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001383 -> initscore=-6.581853
# [LightGBM] [Info] Start training from score -6.581853
# [LightGBM] [Info] Number of positive: 75, number of negative: 122091
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 122166, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000614 -> initscore=-7.395034
# [LightGBM] [Info] Start training from score -7.395034

# %%
multi_model.fit(X_train_ready, Y_train)
Y_pred_proba = multi_model.predict_proba(X_val_ready)

# %%
Y_pred_proba = multi_model.predict_proba(X_test_ready)

# %%
Y_pred_proba_list = np.array(Y_pred_proba)[:, :, 1].T

# %%
Y_pred_proba_list.shape
# Out:
# (75432, 285)

# %%
# tuning the threshold
from sklearn.metrics import f1_score
thresholds = np.linspace(0.05, 0.9, 9)
for t in thresholds:
    y_pred = (Y_pred_proba_list >= t).astype(int)
    print(f"Threshold {t:.1f} → F1 (micro): {f1_score(Y_val, y_pred, average='micro'):.4f}")
# Out:
# Threshold 0.1 → F1 (micro): 0.2425
# Threshold 0.2 → F1 (micro): 0.3270
# Threshold 0.3 → F1 (micro): 0.3173
# Threshold 0.4 → F1 (micro): 0.2802
# Threshold 0.5 → F1 (micro): 0.2379
# Threshold 0.6 → F1 (micro): 0.1935
# Threshold 0.7 → F1 (micro): 0.1556
# Threshold 0.8 → F1 (micro): 0.1153
# Threshold 0.9 → F1 (micro): 0.0794

# %%
best_thresholds = []
for i in range(Y_val.shape[1]):
    best_t, best_f1 = 0, 0
    for t in np.linspace(0.1, 0.9, 9):
        f1 = f1_score(Y_val[:, i], (Y_pred_proba_list[:, i] >= t).astype(int))
        if f1 > best_f1:
            best_t = t
            best_f1 = f1
    best_thresholds.append(best_t)

Y_pred = (Y_pred_proba_list >= best_thresholds).astype(int)

# %%
my_thresholds = [0.2]
for thresold in my_thresholds:
    print(f"threshold: {thresold}")
    Y_pred = (Y_pred_proba >= thresold).astype(int)
    micro_f1 = f1_score(Y_test, Y_pred, average='micro')
    macro_f1 = f1_score(Y_test, Y_pred, average='macro')
    samples_f1 = f1_score(Y_test, Y_pred, average='samples')
    print("Micro F1:", micro_f1)
    print("Macro F1:", macro_f1)
    print("Samples F1:", samples_f1)
# Out:
# threshold: 0.2
# Micro F1: 0.1524552027186267
# Macro F1: 0.15576338254853528
# Samples F1: 0.1975183872284314

# %%
from sklearn.metrics import roc_auc_score, average_precision_score, roc_curve

roc_auc = roc_auc_score(Y_test, Y_pred_proba_list, average='macro')
avg_prec = average_precision_score(Y_test, Y_pred_proba_list, average='macro')

print("ROC-AUC:", roc_auc)
print("Average Precision:", avg_prec)
# Out:
# ROC-AUC: 0.8845609542816047
# Average Precision: 0.5573803295697065

# %%
#plot roc curve with some help from chatgpt
def plot_roc_curves(Y_true, Y_pred_proba, dataset_name="Test"):
    """
    Plots ROC curves for the top 5 most frequent labels + a macro-average ROC curve.
    
    Args:
        Y_true (ndarray): True binary labels, shape (n_samples, n_classes)
        Y_pred_proba (ndarray): Predicted probabilities, shape (n_samples, n_classes)
        dataset_name (str): 'Validation' or 'Test' for plot title
    """
    # --- 1️⃣ Find top 5 most frequent labels ---
    label_freq = np.sum(Y_true, axis=0)
    top5_idx = np.argsort(label_freq)[-5:][::-1]

    print(f"Top 5 most frequent label indices ({dataset_name} set):", top5_idx)

    # --- 2️⃣ Plot ROC curves for top 5 labels ---
    plt.figure(figsize=(8, 6))
    for i in top5_idx:
        fpr, tpr, _ = roc_curve(Y_true[:, i], Y_pred_proba[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curves for Top 5 Most Frequent Classes ({dataset_name} Set)')
    plt.legend()
    plt.grid(True)
    plt.show()

    # --- 3️⃣ Compute and plot macro-average ROC curve ---
    all_fpr = np.unique(np.concatenate([
        roc_curve(Y_true[:, i], Y_pred_proba[:, i])[0] for i in range(Y_true.shape[1])
    ]))
    mean_tpr = np.zeros_like(all_fpr)

    for i in range(Y_true.shape[1]):
        fpr, tpr, _ = roc_curve(Y_true[:, i], Y_pred_proba[:, i])
        mean_tpr += np.interp(all_fpr, fpr, tpr)

    mean_tpr /= Y_true.shape[1]
    roc_auc_macro = auc(all_fpr, mean_tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(all_fpr, mean_tpr, color='blue', lw=2,
             label=f'Macro-average (AUC = {roc_auc_macro:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Macro-average ROC Curve ({dataset_name} Set)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_roc_curves(Y_test, Y_pred_proba_list)
# Out:
# Top 5 most frequent label indices (Test set): [257 175 238 154  29]

# %%
def top_k_labels_for_sample(y_pred_proba, k=5, label_names=None):
    """
    Returns the indices (and optionally names) of the top-k predicted labels for a single sample.

    Args:
        y_pred_proba (array-like): 1D array of predicted probabilities for one sample (shape: n_classes).
        k (int): Number of top labels to return.
        label_names (list, optional): List of label names corresponding to each class index.

    Returns:
        top_indices (ndarray): Indices of top-k labels.
        top_scores (ndarray): Their corresponding probabilities.
        top_labels (list, optional): Label names (if provided).
    """
    y_pred_proba = np.array(y_pred_proba)
    top_indices = np.argsort(y_pred_proba)[::-1][:k]
    top_scores = y_pred_proba[top_indices]
    
    if label_names is not None:
        top_labels = [label_names[i] for i in top_indices]
        return top_indices, top_scores, top_labels
    
    return top_indices, top_scores

# %%
x = 789
k = 5
actual_labels = true_indices = np.where(Y_test[x] == 1)[0]
print(f"Actual labels are: {actual_labels}")
prop_lis_for_x = Y_pred_proba_list[x]
predicted_labels, predicted_score = top_k_labels_for_sample(prop_lis_for_x, k=5)
print(f"Top {k} predicted labels are:")
for (predicted_label, predicted_score) in zip(predicted_labels, predicted_score) :
    print(f"{predicted_label}: {predicted_score}")
# Out:
# Actual labels are: [ 36  62  66 185 197]
# Top 5 predicted labels are:
# 62: 0.999840119437172
# 197: 0.033401037426703035
# 36: 0.026130145688081217
# 66: 0.01741580126888945
# 185: 0.0029209694049191115

# %%
# Model 2:

# %%
# Model 3:
