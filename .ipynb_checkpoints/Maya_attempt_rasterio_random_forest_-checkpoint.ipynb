# %%
import numpy as np
import os
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler, MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, top_k_accuracy_score, auc
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
TRAIN_LOCS_KEY = 'train_locs'
TRAIN_IDS_KEY = 'train_ids'
TAXON_IDS_KEY = 'taxon_ids'
TAXON_NAME_KEY = 'taxon_names'

TEST_LOCS_KEY = 'test_locs'
TEST_IDS_KEY = 'test_pos_inds'

# %% [markdown]
# Reading the file:

# %%
filepath = os.path.join(os.getcwd(), 'species_train.npz')
data = np.load(filepath, allow_pickle=True)
train_locs = data[TRAIN_LOCS_KEY]
train_ids = data[TRAIN_IDS_KEY]
taxon_ids = data[TAXON_IDS_KEY]
taxon_names = data[TAXON_NAME_KEY]

# %% [markdown]
# Reading test file

# %%
test_filepath = os.path.join(os.getcwd(), 'species_test.npz')
test_data = np.load(test_filepath, allow_pickle=True)
test_locs = test_data[TEST_LOCS_KEY]
test_ids = test_data[TEST_IDS_KEY]

# %% [markdown]
# Mapping the taxon ids to taxon latin names:

# %%
species_ids_names = dict(zip(data['taxon_ids'], data['taxon_names']))  # latin names of species

# %% [markdown]
# Create pandas Dataframe for train data:

# %%
df = pd.DataFrame({
    'latitude': train_locs[:, 0],
    'longitude': train_locs[:, 1], 
    'taxon_id': data[TRAIN_IDS_KEY]
})
df['taxon_name'] = [species_ids_names[id] for id in data[TRAIN_IDS_KEY].astype(int)]
df.head()
# Out:
#     latitude   longitude  taxon_id             taxon_name
# 0 -18.286728  143.481247     31529  Lophognathus gilberti
# 1 -13.099798  130.783646     31529  Lophognathus gilberti
# 2 -13.965274  131.695145     31529  Lophognathus gilberti
# 3 -12.853950  132.800507     31529  Lophognathus gilberti
# 4 -12.196790  134.279327     31529  Lophognathus gilberti

# %% [markdown]
# Create pandas Dataframe for test data:

# %%
rows = [
    [test_locs[loc_id][0], test_locs[loc_id][1], taxon_id]
    for taxon_id, loc_ids in zip(taxon_ids, test_ids)
    for loc_id in loc_ids
]

# %%
test_df = pd.DataFrame(rows, columns=["latitude", "longitude", "taxon_id"])
test_df['taxon_name'] = [species_ids_names[id] for id in test_df["taxon_id"].astype(int)]
test_df.head()
# Out:
#     latitude   longitude  taxon_id             taxon_name
# 0 -19.884237  126.052979     31529  Lophognathus gilberti
# 1 -20.219316  124.723953     31529  Lophognathus gilberti
# 2 -20.053690  125.386505     31529  Lophognathus gilberti
# 3 -19.973000  126.462440     31529  Lophognathus gilberti
# 4 -19.962839  124.980362     31529  Lophognathus gilberti

# %%
test_df.shape
# Out:
# (1706646, 4)

# %% [markdown]
# Data Cleanining:

# %% [markdown]
# <small>1. Check for missing or invalid coordinates:</small>

# %%
df = df.dropna(subset=['latitude', 'longitude'])
test_df = test_df.dropna(subset=['latitude', 'longitude'])
df = df[(df['latitude'].between(-90, 90)) & (df['longitude'].between(-180, 180))]
test_df = test_df[(test_df['latitude'].between(-90, 90)) & (test_df['longitude'].between(-180, 180))]
df.shape, test_df.shape
# Out:
# ((272037, 4), (1706646, 4))

# %% [markdown]
# <small>2. Remove any duplicates or nearly duplicates (observations that are extremely close):</small>

# %%
df['lat_rounded'] = df['latitude'].round(5)
df['lon_rounded'] = df['longitude'].round(5)
test_df['lat_rounded'] = test_df['latitude'].round(5)
test_df['lon_rounded'] = test_df['longitude'].round(5)

# %%
df = df.drop_duplicates(subset=['lat_rounded', 'lon_rounded', "taxon_id"])
test_df = test_df.drop_duplicates(subset=['lat_rounded', 'lon_rounded', "taxon_id"])
df.shape, test_df.shape
# Out:
# ((251822, 6), (1706646, 6))

# %% [markdown]
# <small>4. Validate species IDs: </small>

# %%
df['taxon_id'].isna().sum(), test_df['taxon_id'].isna().sum()
# Out:
# (np.int64(0), np.int64(0))

# %% [markdown]
# <small>5. Only keep birds:</small>

# %% [markdown]
# <small>Note: Only run the next 2 blocks one time as they take a few seconds:</small>

# %%
taxa = pd.read_csv('taxa.csv')
birds = taxa[taxa['class'] == 'Aves']
bird_taxon_ids = set(birds['id'])
len(bird_taxon_ids)
# Out:
# 35111

# %%
df = df[df['taxon_id'].isin(bird_taxon_ids)].copy()
test_df = test_df[test_df['taxon_id'].isin(bird_taxon_ids)].copy()
df.shape, test_df.shape
# Out:
# ((162642, 6), (1323320, 6))

# %% [markdown]
# <small>6. Convert to categorical labels:</small>

# %%
le = LabelEncoder()
le.fit(pd.concat([df['taxon_id'], test_df['taxon_id']]))
df['label'] = le.transform(df['taxon_id'])
test_df['label'] = le.transform(test_df['taxon_id'])

# %% [markdown]
# <small>7. Append the climate data</small>

# %%
import rasterio
import numpy as np
import os

base_dir = os.getcwd()  # assumes folders are in the same directory as this notebook

def load_stack(folder_name):
    folder = os.path.join(base_dir, folder_name)
    files = sorted([os.path.join(folder, f) for f in os.listdir(folder) if f.endswith(".tif")])
    if len(files) != 12:
        raise RuntimeError(f"Expected 12 GeoTIFFs in {folder_name}, found {len(files)}.")
    layers = []
    transform = None
    for f in files:
        with rasterio.open(f) as src:
            layers.append(src.read(1))
            transform = src.transform  # all months share the same transform
    return np.stack(layers), transform  # shape: (12, H, W), and affine transform

tmin, transform = load_stack("wc2.1_2.5m_tmin")
tmax, _         = load_stack("wc2.1_2.5m_tmax")
prec, _         = load_stack("wc2.1_2.5m_prec")

print("Stacks loaded. Shapes:",
      "tmin", tmin.shape, "tmax", tmax.shape, "prec", prec.shape)
print("Transform:", transform)
# Out:
# Test data loaded and verified.
# Shape: (1048575, 10)
# Columns: ['latitude', 'longitude', 'taxon_id', 'taxon_name', 'lat_rounded', 'lon_rounded', 'label', 'Tmin_avg', 'Tmax_avg', 'Prec_avg']
# Unique bird species in test set: 217

# %%
#Cleaning the data again as the precipitation values are very large, so I'll normalize them
from rasterio.transform import rowcol
import numpy as np

def get_climate_for_points(df, transform, tmin, tmax, prec, lat_col="latitude", lon_col="longitude"):
    # Convert lat/lon → raster indices
    rows, cols = rowcol(transform, df[lon_col].values, df[lat_col].values)
    rows = np.clip(rows, 0, tmin.shape[1]-1)
    cols = np.clip(cols, 0, tmin.shape[2]-1)

    # Helper: clean up weird values (NoData etc.)
    def clean(arr):
        arr = arr.astype(float)
        arr[arr > 1e4] = np.nan  # remove unrealistic large values
        return arr

    tmin = clean(tmin)
    tmax = clean(tmax)
    prec = clean(prec)

    # Extract values and average across 12 months safely
    tmin_mean = np.nanmean(tmin[:, rows, cols], axis=0)
    tmax_mean = np.nanmean(tmax[:, rows, cols], axis=0)
    prec_mean = np.nanmean(prec[:, rows, cols], axis=0)

    return tmin_mean, tmax_mean, prec_mean

# %%
tmin_avg, tmax_avg, prec_avg = get_climate_for_points(df, transform, tmin, tmax, prec)

# %%
test_tmin_avg, test_tmax_avg, test_prec_avg = get_climate_for_points(test_df, transform, tmin, tmax, prec)

# %%
df["Tmin_avg"] = tmin_avg
df["Tmax_avg"] = tmax_avg
df["Prec_avg"] = prec_avg

df[["latitude","longitude","Tmin_avg","Tmax_avg","Prec_avg"]].head()

# %%
test_df["Tmin_avg"] = test_tmin_avg
test_df["Tmax_avg"] = test_tmax_avg
test_df["Prec_avg"] = test_prec_avg

test_df[["latitude","longitude","Tmin_avg","Tmax_avg","Prec_avg"]].head()

# %%
out_path = "bird_species_rerun_with_averaged_climate.csv"
df.to_csv(out_path, index=False)
out_path, df.shape

# %%
out_path = "test_bird_species_rerun_with_averaged_climate.csv"
test_df.to_csv(out_path, index=False)
out_path, test_df.shape

# %%
df = pd.read_csv('bird_species_rerun_with_averaged_climate.csv')

# %%
test_df = pd.read_csv('test_bird_species_rerun_with_averaged_climate.csv')

# %% [markdown]
# <small>8. Clean the climate data</small>

# %%
df['Tmin_avg'] = df['Tmin_avg'].mask(df['Tmin_avg'] < -1e+30, np.nan)
df['Tmax_avg'] = df['Tmax_avg'].mask(df['Tmax_avg'] < -1e+30, np.nan)
df['Prec_avg'] = df['Prec_avg'].mask(df['Prec_avg'] < 0, np.nan)
print(f"Shape with nan data: {df.shape}")
df = df.dropna(subset=['Tmin_avg', 'Tmax_avg', 'Prec_avg'])
print(f"Shape without nan data: {df.shape}")
# Out:
# Shape with nan data: (151391, 10)
# Shape without nan data: (150194, 10)

# %%
len(test_df)
# Out:
# 1048575

# %%
test_df['Tmin_avg'] = test_df['Tmin_avg'].mask(test_df['Tmin_avg'] < -1e+30, np.nan)
test_df['Tmax_avg'] = test_df['Tmax_avg'].mask(test_df['Tmax_avg'] < -1e+30, np.nan)
test_df['Prec_avg'] = test_df['Prec_avg'].mask(test_df['Prec_avg'] < 0, np.nan)
print(f"Shape with nan data: {test_df.shape}")
test_df = test_df.dropna(subset=['Tmin_avg', 'Tmax_avg', 'Prec_avg'])
print(f"Shape without nan data: {test_df.shape}")
# Out:
# Shape with nan data: (1048575, 10)
# Shape without nan data: (725335, 10)

# %% [markdown]
# <small>Note: mention in the report that we lost a lot of data because of removing NaN temperature, in the ociens mainly.</small>

# %%
(df['Tmax_avg'] < df['Tmin_avg']).sum(), (test_df['Tmax_avg'] < test_df['Tmin_avg']).sum()
# Out:
# (np.int64(0), np.int64(0))

# %% [markdown]
# <small>9. Split the data to x and y and normalize the climate features</small>

# %%
from sklearn.preprocessing import StandardScaler
X_data = df.drop(columns=['taxon_id', 'taxon_name', 'lat_rounded', 'lon_rounded', 'label'])
y_data = df['label']
climate_features = ['Tmin_avg', 'Tmax_avg', 'Prec_avg']
non_scaled_features = ['latitude', 'longitude']
# scale climate 
scaler = StandardScaler()
scaler.fit(X_data[climate_features])
X_scaled = X_data.copy()
X_scaled[climate_features] = scaler.transform(X_data[climate_features])
X_scaled.describe()
# Out:
#             latitude      longitude      Tmin_avg      Tmax_avg      Prec_avg
# count  150194.000000  150194.000000  1.501940e+05  1.501940e+05  1.501940e+05
# mean       15.544443      -9.343506 -1.937749e-16 -1.271648e-16  1.831779e-16
# std        32.019650      95.974393  1.000003e+00  1.000003e+00  1.000003e+00
# min       -75.284950    -178.060320 -6.684864e+00 -6.659755e+00 -1.640339e+00
# 25%       -19.905400     -96.408343 -6.481463e-01 -7.715034e-01 -6.507734e-01
# 50%        27.829345     -47.548143  1.810142e-02  1.161172e-01 -1.759906e-01
# 75%        41.539592      73.949602  6.747353e-01  7.379541e-01  3.944445e-01
# max        72.515430     178.827590  2.290127e+00  2.249082e+00  1.336141e+01

# %%
X_test = test_df.drop(columns=['taxon_id', 'taxon_name', 'lat_rounded', 'lon_rounded', 'label'])
y_test = test_df['label']
climate_features = ['Tmin_avg', 'Tmax_avg', 'Prec_avg']
non_scaled_features = ['latitude', 'longitude']
# scale climate 
X_test_scaled = X_test.copy()
X_test_scaled[climate_features] = scaler.transform(X_test[climate_features])
X_test_scaled.describe()
# Out:
#             latitude      longitude       Tmin_avg       Tmax_avg  \
# count  725335.000000  725335.000000  725335.000000  725335.000000
# mean       12.826231      19.422611       0.217934       0.317319
# std        29.241388      76.108346       1.436795       1.414491
# min       -82.872560    -179.933670      -6.914783      -7.159502
# 25%       -12.800034     -53.767310      -0.750359      -0.667508
# 50%        10.389260      26.550740       0.653594       0.896566
# 75%        38.650130      78.060814       1.392233       1.370680
# max        82.845260     179.994780       2.635286       2.399846
#
#             Prec_avg
# count  725335.000000
# mean       -0.000481
# std         1.253564
# min        -1.640339
# 25%        -0.922078
# 50%        -0.353382
# 75%         0.603140
# max        12.253581

# %% [markdown]
# Split the data into train and validation sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y_data,
                                                  test_size=0.2,
                                                  random_state=42, 
                                                  stratify=y_data)

X_train.to_csv('X_train.csv', index=False)
X_val.to_csv('X_val.csv', index=False)
y_train.to_csv('y_train.csv', index=False)
y_val.to_csv('y_val.csv', index=False)

# %% [markdown]
# loading again the split

# %%
X_train = pd.read_csv("X_train.csv")
X_val   = pd.read_csv("X_val.csv")
y_train = pd.read_csv("y_train.csv")
y_val   = pd.read_csv("y_val.csv")

y_train = y_train.values.ravel()
y_val   = y_val.values.ravel()

print("Train/Val data loaded successfully!")
print(f"X_train: {X_train.shape}, X_val: {X_val.shape}")
print(f"y_train: {y_train.shape}, y_val: {y_val.shape}")
# Out:
# Train/Val data loaded successfully!
# X_train: (120155, 5), X_val: (30039, 5)
# y_train: (120155,), y_val: (30039,)

# %% [markdown]
# Random forest (training for 1 vs all)

# %%
# Train one Random Forest per bird species to predict its presence (1) vs absence (0)
# using climatic + spatial variables. Displays scientific species names for clarity.

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, roc_auc_score

#1️. Create a mapping between label IDs and species names
# Ensure 'bird_species_with_climate.csv' has 'label' and 'taxon_name' columns
df_climate = pd.read_csv("bird_species_with_climate.csv")
species_map = dict(zip(df_climate["label"], df_climate["taxon_name"]))

#2️. Prepare training DataFrame
df_train = X_train.copy()
df_train["label"] = y_train

# Get unique species IDs
species_list = np.unique(y_train)
results = []

#3. Train binary models per species
for sp in species_list:
    species_name = species_map.get(sp, f"Species {sp}")  # fallback if name not found
    print(f"\nTraining binary model for species: {species_name} ...")

    # Binary target: 1 if this species, else 0
    df_train["target"] = (df_train["label"] == sp).astype(int)
    X_tr = df_train.drop(columns=["label", "target"])
    y_tr = df_train["target"]

    # Lightweight Random Forest (optimized to prevent kernel crash)
    rf = RandomForestClassifier(
        n_estimators=60,
        max_depth=18,
        min_samples_leaf=3,
        class_weight='balanced',
        n_jobs=2,
        random_state=42
    )

    rf.fit(X_tr, y_tr)

    # Validation
    X_v = X_val
    y_v = (y_val == sp).astype(int)
    y_pred = rf.predict(X_v)
    y_proba = rf.predict_proba(X_v)[:, 1]

    f1  = f1_score(y_v, y_pred)
    auc = roc_auc_score(y_v, y_proba)

    print(f"Trained {species_name} — AUC: {auc:.3f}")

    # Store metrics + model
    results.append({
        "species_id": sp,
        "species_name": species_name,
        "f1_score": f1,
        "auc": auc,
        "model": rf
    })

#4. Combine results
results_df = pd.DataFrame(results)
print("\n Model training completed for all species!")
print(f"Total models trained: {len(results_df)}")
print(results_df[["species_name", "f1_score", "auc"]].head())
# Out:
# Training binary model for species: Aramides saracura ...
# Trained Aramides saracura — AUC: 0.924
#
# Training binary model for species: Aramides ypecaha ...
# Trained Aramides ypecaha — AUC: 0.956
#
# Training binary model for species: Fulica cristata ...
# Trained Fulica cristata — AUC: 0.981
#
# Training binary model for species: Tetraogallus tibetanus ...
# Trained Tetraogallus tibetanus — AUC: 1.000
#
# Training binary model for species: Alectoris barbara ...
# Trained Alectoris barbara — AUC: 1.000
#
# Training binary model for species: Gallus sonneratii ...
# Trained Gallus sonneratii — AUC: 0.957
#
# Training binary model for species: Bonasa umbellus ...
# Trained Bonasa umbellus — AUC: 0.986
#
# Training binary model for species: Tetrao urogallus ...
# Trained Tetrao urogallus — AUC: 0.992
#
# Training binary model for species: Tympanuchus pallidicinctus ...
# Trained Tympanuchus pallidicinctus — AUC: 1.000
#
# Training binary model for species: Ptilopachus petrosus ...
# Trained Ptilopachus petrosus — AUC: 0.849
#
# Training binary model for species: Centrocercus urophasianus ...
# Trained Centrocercus urophasianus — AUC: 0.982
#
# Training binary model for species: Centropus superciliosus ...
# Trained Centropus superciliosus — AUC: 0.980
#
# Training binary model for species: Centropus phasianinus ...
# Trained Centropus phasianinus — AUC: 0.987
#
# Training binary model for species: Cacomantis flabelliformis ...
# Trained Cacomantis flabelliformis — AUC: 0.949
#
# Training binary model for species: Penelope montagnii ...
# Trained Penelope montagnii — AUC: 0.974
#
# Training binary model for species: Merops hirundineus ...
# Trained Merops hirundineus — AUC: 0.966
#
# Training binary model for species: Merops orientalis ...
# Trained Merops orientalis — AUC: 0.981
#
# Training binary model for species: Coracias cyanogaster ...
# Trained Coracias cyanogaster — AUC: 0.999
#
# Training binary model for species: Columba leuconota ...
# Trained Columba leuconota — AUC: 0.799
#
# Training binary model for species: Columba leucomela ...
# Trained Columba leucomela — AUC: 0.982
#
# Training binary model for species: Patagioenas flavirostris ...
# Trained Patagioenas flavirostris — AUC: 0.990
#
# Training binary model for species: Treron waalia ...
# Trained Treron waalia — AUC: 0.899
#
# Training binary model for species: Columbina inca ...
# Trained Columbina inca — AUC: 0.977
#
# Training binary model for species: Geophaps scripta ...
# Trained Geophaps scripta — AUC: 0.999
#
# Training binary model for species: Platalea alba ...
# Trained Platalea alba — AUC: 0.979
#
# Training binary model for species: Spheniscus demersus ...
# Trained Spheniscus demersus — AUC: 1.000
#
# Training binary model for species: Gallinago hardwickii ...
# Trained Gallinago hardwickii — AUC: 0.938
#
# Training binary model for species: Oceanites oceanicus ...
# Trained Oceanites oceanicus — AUC: 0.831
#
# Training binary model for species: Phoebetria palpebrata ...
# Trained Phoebetria palpebrata — AUC: 1.000
#
# Training binary model for species: Podiceps cristatus ...
# Trained Podiceps cristatus — AUC: 0.955
#
# Training binary model for species: Phalacrocorax neglectus ...
# Trained Phalacrocorax neglectus — AUC: 0.999
#
# Training binary model for species: Larus occidentalis ...
# Trained Larus occidentalis — AUC: 0.990
#
# Training binary model for species: Anous stolidus ...
# Trained Anous stolidus — AUC: 0.952
#
# Training binary model for species: Phaetusa simplex ...
# Trained Phaetusa simplex — AUC: 0.996
#
# Training binary model for species: Fregata minor ...
# Trained Fregata minor — AUC: 0.983
#
# Training binary model for species: Falco dickinsoni ...
# Trained Falco dickinsoni — AUC: 0.995
#
# Training binary model for species: Falco sparverius ...
# Trained Falco sparverius — AUC: 0.860
#
# Training binary model for species: Ibycter americanus ...
# Trained Ibycter americanus — AUC: 0.924
#
# Training binary model for species: Coragyps atratus ...
# Trained Coragyps atratus — AUC: 0.923
#
# Training binary model for species: Charadrius vociferus ...
# Trained Charadrius vociferus — AUC: 0.866
#
# Training binary model for species: Hieraaetus morphnoides ...
# Trained Hieraaetus morphnoides — AUC: 0.977
#
# Training binary model for species: Circus ranivorus ...
# Trained Circus ranivorus — AUC: 0.950
#
# Training binary model for species: Circus maurus ...
# Trained Circus maurus — AUC: 0.981
#
# Training binary model for species: Terathopius ecaudatus ...
# Trained Terathopius ecaudatus — AUC: 0.986
#
# Training binary model for species: Buteogallus meridionalis ...
# Trained Buteogallus meridionalis — AUC: 0.979
#
# Training binary model for species: Aviceda subcristata ...
# Trained Aviceda subcristata — AUC: 0.967
#
# Training binary model for species: Gyps coprotheres ...
# Trained Gyps coprotheres — AUC: 0.980
#
# Training binary model for species: Gyps himalayensis ...
# Trained Gyps himalayensis — AUC: 0.979
#
# Training binary model for species: Butastur rufipennis ...
# Trained Butastur rufipennis — AUC: 0.976
#
# Training binary model for species: Torgos tracheliotos ...
# Trained Torgos tracheliotos — AUC: 0.978
#
# Training binary model for species: Kaupifalco monogrammicus ...
# Trained Kaupifalco monogrammicus — AUC: 0.971
#
# Training binary model for species: Buceros rhinoceros ...
# Trained Buceros rhinoceros — AUC: 1.000
#
# Training binary model for species: Phaethornis ruber ...
# Trained Phaethornis ruber — AUC: 0.964
#
# Training binary model for species: Heliodoxa aurescens ...
# Trained Heliodoxa aurescens — AUC: 1.000
#
# Training binary model for species: Thalurania glaucopis ...
# Trained Thalurania glaucopis — AUC: 0.995
#
# Training binary model for species: Lesbia victoriae ...
# Trained Lesbia victoriae — AUC: 0.998
#
# Training binary model for species: Coeligena helianthea ...
# Trained Coeligena helianthea — AUC: 0.909
#
# Training binary model for species: Lophornis ornatus ...
# Trained Lophornis ornatus — AUC: 0.875
#
# Training binary model for species: Selasphorus flammula ...
# Trained Selasphorus flammula — AUC: 0.981
#
# Training binary model for species: Anas gracilis ...
# Trained Anas gracilis — AUC: 0.960
#
# Training binary model for species: Anas sparsa ...
# Trained Anas sparsa — AUC: 0.991
#
# Training binary model for species: Aythya novaeseelandiae ...
# Trained Aythya novaeseelandiae — AUC: 0.995
#
# Training binary model for species: Chloephaga poliocephala ...
# Trained Chloephaga poliocephala — AUC: 1.000
#
# Training binary model for species: Biziura lobata ...
# Trained Biziura lobata — AUC: 0.908
#
# Training binary model for species: Ammomanes deserti ...
# Trained Ammomanes deserti — AUC: 0.983
#
# Training binary model for species: Polioptila californica ...
# Trained Polioptila californica — AUC: 0.996
#
# Training binary model for species: Troglodytes aedon ...
# Trained Troglodytes aedon — AUC: 0.857
#
# Training binary model for species: Thryomanes bewickii ...
# Trained Thryomanes bewickii — AUC: 0.946
#
# Training binary model for species: Malcorus pectoralis ...
# Trained Malcorus pectoralis — AUC: 0.849
#
# Training binary model for species: Prinia subflava ...
# Trained Prinia subflava — AUC: 0.976
#
# Training binary model for species: Prinia maculosa ...
# Trained Prinia maculosa — AUC: 0.986
#
# Training binary model for species: Climacteris picumnus ...
# Trained Climacteris picumnus — AUC: 0.979
#
# Training binary model for species: Climacteris rufus ...
# Trained Climacteris rufus — AUC: 0.961
#
# Training binary model for species: Oriolus auratus ...
# Trained Oriolus auratus — AUC: 0.918
#
# Training binary model for species: Pachycephala rufiventris ...
# Trained Pachycephala rufiventris — AUC: 0.959
#
# Training binary model for species: Artamus minor ...
# Trained Artamus minor — AUC: 0.686
#
# Training binary model for species: Artamus personatus ...
# Trained Artamus personatus — AUC: 0.948
#
# Training binary model for species: Artamus fuscus ...
# Trained Artamus fuscus — AUC: 0.992
#
# Training binary model for species: Laniarius bicolor ...
# Trained Laniarius bicolor — AUC: 0.856
#
# Training binary model for species: Dicrurus forficatus ...
# Trained Dicrurus forficatus — AUC: 1.000
#
# Training binary model for species: Dicrurus macrocercus ...
# Trained Dicrurus macrocercus — AUC: 0.984
#
# Training binary model for species: Batis molitor ...
# Trained Batis molitor — AUC: 0.966
#
# Training binary model for species: Tchagra australis ...
# Trained Tchagra australis — AUC: 0.949
#
# Training binary model for species: Platysteira cyanea ...
# Trained Platysteira cyanea — AUC: 0.968
#
# Training binary model for species: Nucifraga columbiana ...
# Trained Nucifraga columbiana — AUC: 0.998
#
# Training binary model for species: Pachyramphus castaneus ...
# Trained Pachyramphus castaneus — AUC: 0.956
#
# Training binary model for species: Procnias tricarunculatus ...
# Trained Procnias tricarunculatus — AUC: 0.975
#
# Training binary model for species: Cotinga cayana ...
# Trained Cotinga cayana — AUC: 0.960
#
# Training binary model for species: Cotinga nattererii ...
# Trained Cotinga nattererii — AUC: 1.000
#
# Training binary model for species: Cardinalis sinuatus ...
# Trained Cardinalis sinuatus — AUC: 0.981
#
# Training binary model for species: Cardinalis cardinalis ...
# Trained Cardinalis cardinalis — AUC: 0.915
#
# Training binary model for species: Spizella pusilla ...
# Trained Spizella pusilla — AUC: 0.943
#
# Training binary model for species: Euphonia pectoralis ...
# Trained Euphonia pectoralis — AUC: 0.996
#
# Training binary model for species: Icterus chrysater ...
# Trained Icterus chrysater — AUC: 0.995
#
# Training binary model for species: Geospiza magnirostris ...
# Trained Geospiza magnirostris — AUC: 1.000
#
# Training binary model for species: Melozone kieneri ...
# Trained Melozone kieneri — AUC: 0.972
#
# Training binary model for species: Tangara cyanocephala ...
# Trained Tangara cyanocephala — AUC: 0.914
#
# Training binary model for species: Quiscalus quiscula ...
# Trained Quiscalus quiscula — AUC: 0.934
#
# Training binary model for species: Leucosticte australis ...
# Trained Leucosticte australis — AUC: 1.000
#
# Training binary model for species: Granatellus sallaei ...
# Trained Granatellus sallaei — AUC: 1.000
#
# Training binary model for species: Carpodacus erythrinus ...
# Trained Carpodacus erythrinus — AUC: 0.965
#
# Training binary model for species: Pinicola enucleator ...
# Trained Pinicola enucleator — AUC: 0.975
#
# Training binary model for species: Diglossa plumbea ...
# Trained Diglossa plumbea — AUC: 0.999
#
# Training binary model for species: Tachyphonus coronatus ...
# Trained Tachyphonus coronatus — AUC: 0.973
#
# Training binary model for species: Phrygilus atriceps ...
# Trained Phrygilus atriceps — AUC: 1.000
#
# Training binary model for species: Pooecetes gramineus ...
# Trained Pooecetes gramineus — AUC: 0.928
#
# Training binary model for species: Icteria virens ...
# Trained Icteria virens — AUC: 0.924
#
# Training binary model for species: Molothrus ater ...
# Trained Molothrus ater — AUC: 0.879
#
# Training binary model for species: Dacnis cayana ...
# Trained Dacnis cayana — AUC: 0.989
#
# Training binary model for species: Calamospiza melanocorys ...
# Trained Calamospiza melanocorys — AUC: 0.967
#
# Training binary model for species: Trichothraupis melanops ...
# Trained Trichothraupis melanops — AUC: 0.965
#
# Training binary model for species: Xiphocolaptes promeropirhynchus ...
# Trained Xiphocolaptes promeropirhynchus — AUC: 0.949
#
# Training binary model for species: Lochmias nematura ...
# Trained Lochmias nematura — AUC: 0.928
#
# Training binary model for species: Lepidocolaptes leucogaster ...
# Trained Lepidocolaptes leucogaster — AUC: 0.978
#
# Training binary model for species: Hirundo smithii ...
# Trained Hirundo smithii — AUC: 0.978
#
# Training binary model for species: Stelgidopteryx serripennis ...
# Trained Stelgidopteryx serripennis — AUC: 0.888
#
# Training binary model for species: Stelgidopteryx ruficollis ...
# Trained Stelgidopteryx ruficollis — AUC: 0.979
#
# Training binary model for species: Lanius ludovicianus ...
# Trained Lanius ludovicianus — AUC: 0.937
#
# Training binary model for species: Lanius collurio ...
# Trained Lanius collurio — AUC: 0.952
#
# Training binary model for species: Lanius cabanisi ...
# Trained Lanius cabanisi — AUC: 0.999
#
# Training binary model for species: Malurus elegans ...
# Trained Malurus elegans — AUC: 0.979
#
# Training binary model for species: Acanthorhynchus superciliosus ...
# Trained Acanthorhynchus superciliosus — AUC: 0.865
#
# Training binary model for species: Meliphaga lewinii ...
# Trained Meliphaga lewinii — AUC: 0.965
#
# Training binary model for species: Philemon corniculatus ...
# Trained Philemon corniculatus — AUC: 0.964
#
# Training binary model for species: Myzomela sanguinolenta ...
# Trained Myzomela sanguinolenta — AUC: 0.949
#
# Training binary model for species: Lichmera indistincta ...
# Trained Lichmera indistincta — AUC: 0.976
#
# Training binary model for species: Phylidonyris pyrrhopterus ...
# Trained Phylidonyris pyrrhopterus — AUC: 0.973
#
# Training binary model for species: Turdus pilaris ...
# Trained Turdus pilaris — AUC: 0.960
#
# Training binary model for species: Turdus merula ...
# Trained Turdus merula — AUC: 0.957
#
# Training binary model for species: Turdus viscivorus ...
# Trained Turdus viscivorus — AUC: 0.971
#
# Training binary model for species: Turdus albicollis ...
# Trained Turdus albicollis — AUC: 0.859
#
# Training binary model for species: Turdus rufitorques ...
# Trained Turdus rufitorques — AUC: 1.000
#
# Training binary model for species: Turdus fuscater ...
# Trained Turdus fuscater — AUC: 0.997
#
# Training binary model for species: Cossypha heuglini ...
# Trained Cossypha heuglini — AUC: 0.938
#
# Training binary model for species: Oenanthe lugens ...
# Trained Oenanthe lugens — AUC: 0.999
#
# Training binary model for species: Oenanthe leucopyga ...
# Trained Oenanthe leucopyga — AUC: 1.000
#
# Training binary model for species: Oenanthe pileata ...
# Trained Oenanthe pileata — AUC: 0.939
#
# Training binary model for species: Saxicola caprata ...
# Trained Saxicola caprata — AUC: 0.978
#
# Training binary model for species: Myadestes melanops ...
# Trained Myadestes melanops — AUC: 1.000
#
# Training binary model for species: Luscinia luscinia ...
# Trained Luscinia luscinia — AUC: 0.981
#
# Training binary model for species: Enicurus scouleri ...
# Trained Enicurus scouleri — AUC: 0.999
#
# Training binary model for species: Enicurus leschenaulti ...
# Trained Enicurus leschenaulti — AUC: 1.000
#
# Training binary model for species: Pogonocichla stellata ...
# Trained Pogonocichla stellata — AUC: 0.915
#
# Training binary model for species: Orthonyx temminckii ...
# Trained Orthonyx temminckii — AUC: 0.978
#
# Training binary model for species: Acanthiza nana ...
# Trained Acanthiza nana — AUC: 0.957
#
# Training binary model for species: Acanthiza reguloides ...
# Trained Acanthiza reguloides — AUC: 0.964
#
# Training binary model for species: Gerygone igata ...
# Trained Gerygone igata — AUC: 0.991
#
# Training binary model for species: Sericornis frontalis ...
# Trained Sericornis frontalis — AUC: 0.970
#
# Training binary model for species: Aphelocephala leucopsis ...
# Trained Aphelocephala leucopsis — AUC: 0.942
#
# Training binary model for species: Pardalotus striatus ...
# Trained Pardalotus striatus — AUC: 0.963
#
# Training binary model for species: Smicrornis brevirostris ...
# Trained Smicrornis brevirostris — AUC: 0.975
#
# Training binary model for species: Baeolophus bicolor ...
# Trained Baeolophus bicolor — AUC: 0.957
#
# Training binary model for species: Anthus rufulus ...
# Trained Anthus rufulus — AUC: 0.986
#
# Training binary model for species: Ploceus xanthops ...
# Trained Ploceus xanthops — AUC: 0.956
#
# Training binary model for species: Passer montanus ...
# Trained Passer montanus — AUC: 0.957
#
# Training binary model for species: Sporopipes frontalis ...
# Trained Sporopipes frontalis — AUC: 0.997
#
# Training binary model for species: Vidua regia ...
# Trained Vidua regia — AUC: 0.890
#
# Training binary model for species: Uraeginthus cyanocephalus ...
# Trained Uraeginthus cyanocephalus — AUC: 0.999
#
# Training binary model for species: Neochmia temporalis ...
# Trained Neochmia temporalis — AUC: 0.963
#
# Training binary model for species: Macronyx croceus ...
# Trained Macronyx croceus — AUC: 0.992
#
# Training binary model for species: Plocepasser mahali ...
# Trained Plocepasser mahali — AUC: 0.979
#
# Training binary model for species: Petroica rosea ...
# Trained Petroica rosea — AUC: 0.945
#
# Training binary model for species: Petroica goodenovii ...
# Trained Petroica goodenovii — AUC: 0.967
#
# Training binary model for species: Petroica rodinogaster ...
# Trained Petroica rodinogaster — AUC: 0.936
#
# Training binary model for species: Chiroxiphia caudata ...
# Trained Chiroxiphia caudata — AUC: 0.995
#
# Training binary model for species: Pomatostomus temporalis ...
# Trained Pomatostomus temporalis — AUC: 0.986
#
# Training binary model for species: Pycnonotus luteolus ...
# Trained Pycnonotus luteolus — AUC: 0.992
#
# Training binary model for species: Alophoixus pallidus ...
# Trained Alophoixus pallidus — AUC: 0.928
#
# Training binary model for species: Spizixos semitorques ...
# Trained Spizixos semitorques — AUC: 0.999
#
# Training binary model for species: Mimus longicaudatus ...
# Trained Mimus longicaudatus — AUC: 1.000
#
# Training binary model for species: Toxostoma bendirei ...
# Trained Toxostoma bendirei — AUC: 0.974
#
# Training binary model for species: Lamprotornis pulcher ...
# Trained Lamprotornis pulcher — AUC: 0.999
#
# Training binary model for species: Onychognathus tristramii ...
# Trained Onychognathus tristramii — AUC: 1.000
#
# Training binary model for species: Melanotis caerulescens ...
# Trained Melanotis caerulescens — AUC: 0.987
#
# Training binary model for species: Chamaea fasciata ...
# Trained Chamaea fasciata — AUC: 0.991
#
# Training binary model for species: Sylvia borin ...
# Trained Sylvia borin — AUC: 0.947
#
# Training binary model for species: Myiarchus ferox ...
# Trained Myiarchus ferox — AUC: 0.911
#
# Training binary model for species: Contopus sordidulus ...
# Trained Contopus sordidulus — AUC: 0.949
#
# Training binary model for species: Empidonax atriceps ...
# Trained Empidonax atriceps — AUC: 1.000
#
# Training binary model for species: Attila rufus ...
# Trained Attila rufus — AUC: 0.927
#
# Training binary model for species: Tyrannus tyrannus ...
# Trained Tyrannus tyrannus — AUC: 0.914
#
# Training binary model for species: Camptostoma obsoletum ...
# Trained Camptostoma obsoletum — AUC: 0.977
#
# Training binary model for species: Sayornis saya ...
# Trained Sayornis saya — AUC: 0.946
#
# Training binary model for species: Poecilotriccus plumbeiceps ...
# Trained Poecilotriccus plumbeiceps — AUC: 0.939
#
# Training binary model for species: Cnemotriccus fuscatus ...
# Trained Cnemotriccus fuscatus — AUC: 0.882
#
# Training binary model for species: Tachuris rubrigastra ...
# Trained Tachuris rubrigastra — AUC: 0.991
#
# Training binary model for species: Alectrurus risora ...
# Trained Alectrurus risora — AUC: 1.000
#
# Training binary model for species: Campethera nubica ...
# Trained Campethera nubica — AUC: 0.992
#
# Training binary model for species: Melanerpes erythrocephalus ...
# Trained Melanerpes erythrocephalus — AUC: 0.952
#
# Training binary model for species: Melanerpes chrysogenys ...
# Trained Melanerpes chrysogenys — AUC: 0.988
#
# Training binary model for species: Selenidera maculirostris ...
# Trained Selenidera maculirostris — AUC: 0.998
#
# Training binary model for species: Poicephalus cryptoxanthus ...
# Trained Poicephalus cryptoxanthus — AUC: 0.994
#
# Training binary model for species: Poicephalus meyeri ...
# Trained Poicephalus meyeri — AUC: 0.922
#
# Training binary model for species: Aratinga weddellii ...
# Trained Aratinga weddellii — AUC: 0.999
#
# Training binary model for species: Enicognathus ferrugineus ...
# Trained Enicognathus ferrugineus — AUC: 1.000
#
# Training binary model for species: Hydropsalis climacocerca ...
# Trained Hydropsalis climacocerca — AUC: 0.948
#
# Training binary model for species: Megascops asio ...
# Trained Megascops asio — AUC: 0.956
#
# Training binary model for species: Athene cunicularia ...
# Trained Athene cunicularia — AUC: 0.962
#
# Training binary model for species: Athene brama ...
# Trained Athene brama — AUC: 0.983
#
# Training binary model for species: Dromaius novaehollandiae ...
# Trained Dromaius novaehollandiae — AUC: 0.971
#
# Training binary model for species: Crypturellus soui ...
# Trained Crypturellus soui — AUC: 0.827
#
# Training binary model for species: Crypturellus cinnamomeus ...
# Trained Crypturellus cinnamomeus — AUC: 0.952
#
# Training binary model for species: Pygoscelis antarcticus ...
# Trained Pygoscelis antarcticus — AUC: 1.000
#
# Training binary model for species: Chrysomus ruficapillus ...
# Trained Chrysomus ruficapillus — AUC: 0.995
#
# Training binary model for species: Chloropsis jerdoni ...
# Trained Chloropsis jerdoni — AUC: 0.961
#
# Training binary model for species: Cisticola fulvicapilla ...
# Trained Cisticola fulvicapilla — AUC: 0.962
#
# Training binary model for species: Notharchus hyperrhynchus ...
# Trained Notharchus hyperrhynchus — AUC: 0.989
#
# Training binary model for species: Peucaea aestivalis ...
# Trained Peucaea aestivalis — AUC: 0.977
#
# Training binary model for species: Phoenicurus erythrogastrus ...
# Trained Phoenicurus erythrogastrus — AUC: 0.985
#
# Training binary model for species: Tchagra senegalus ...
# Trained Tchagra senegalus — AUC: 0.977
#
# Training binary model for species: Cacomantis passerinus ...
# Trained Cacomantis passerinus — AUC: 0.958
#
# Training binary model for species: Acrocephalus gracilirostris ...
# Trained Acrocephalus gracilirostris — AUC: 0.978
#
# Training binary model for species: Chaetops aurantius ...
# Trained Chaetops aurantius — AUC: 1.000
#
# Training binary model for species: Cincloramphus cruralis ...
# Trained Cincloramphus cruralis — AUC: 0.903
#
# Training binary model for species: Lybius torquatus ...
# Trained Lybius torquatus — AUC: 0.964
#
# Training binary model for species: Phylloscopus trochiloides ...
# Trained Phylloscopus trochiloides — AUC: 0.923
#
# Training binary model for species: Pterocles bicinctus ...
# Trained Pterocles bicinctus — AUC: 0.950
#
# Training binary model for species: Regulus ignicapilla ...
# Trained Regulus ignicapilla — AUC: 0.982
#
# Training binary model for species: Semnornis ramphastinus ...
# Trained Semnornis ramphastinus — AUC: 0.970
#
# Training binary model for species: Picus viridis ...
# Trained Picus viridis — AUC: 0.975
#
# Training binary model for species: Thamnolaea cinnamomeiventris ...
# Trained Thamnolaea cinnamomeiventris — AUC: 0.987
#
# Training binary model for species: Micronisus gabar ...
# Trained Micronisus gabar — AUC: 0.975
#
# Training binary model for species: Aquila spilogaster ...
# Trained Aquila spilogaster — AUC: 0.938
#
# Training binary model for species: Hieraaetus wahlbergi ...
# Trained Hieraaetus wahlbergi — AUC: 0.951
#
# Training binary model for species: Sternula superciliaris ...
# Trained Sternula superciliaris — AUC: 0.980
#
# Training binary model for species: Ceyx azureus ...
# Trained Ceyx azureus — AUC: 0.982
#
# Training binary model for species: Coracias naevius ...
# Trained Coracias naevius — AUC: 0.972
#
# Training binary model for species: Carterornis leucotis ...
# Trained Carterornis leucotis — AUC: 0.746
#
# Training binary model for species: Heteromyias cinereifrons ...
# Trained Heteromyias cinereifrons — AUC: 1.000
#
# Training binary model for species: Calendulauda sabota ...
# Trained Calendulauda sabota — AUC: 0.941
#
# Training binary model for species: Calendulauda albescens ...
# Trained Calendulauda albescens — AUC: 0.999
#
# Training binary model for species: Cecropis abyssinica ...
# Trained Cecropis abyssinica — AUC: 0.964
#
# Training binary model for species: Cecropis senegalensis ...
# Trained Cecropis senegalensis — AUC: 0.985
#
# Training binary model for species: Poecile atricapillus ...
# Trained Poecile atricapillus — AUC: 0.955
#
# Training binary model for species: Copsychus fulicatus ...
# Trained Copsychus fulicatus — AUC: 0.962
#
# Training binary model for species: Turdus simillimus ...
# Trained Turdus simillimus — AUC: 0.936
#
# Training binary model for species: Cinnyris talatala ...
# Trained Cinnyris talatala — AUC: 0.983
#
# Training binary model for species: Cinnyris fuscus ...
# Trained Cinnyris fuscus — AUC: 0.922
#
# Training binary model for species: Acanthis flammea ...
# Trained Acanthis flammea — AUC: 0.933
#
# Training binary model for species: Spinus psaltria ...
# Trained Spinus psaltria — AUC: 0.943
#
# Training binary model for species: Spinus tristis ...
# Trained Spinus tristis — AUC: 0.902
#
# Training binary model for species: Granatina granatina ...
# Trained Granatina granatina — AUC: 0.944
#
# Training binary model for species: Haemorhous purpureus ...
# Trained Haemorhous purpureus — AUC: 0.927
#
# Training binary model for species: Lalage melanoptera ...
# Trained Lalage melanoptera — AUC: 0.991
#
# Training binary model for species: Iduna caligata ...
# Trained Iduna caligata — AUC: 0.971
#
# Training binary model for species: Vidua paradisaea ...
# Trained Vidua paradisaea — AUC: 0.968
#
# Training binary model for species: Calandrella cinerea ...
# Trained Calandrella cinerea — AUC: 0.959
#
# Training binary model for species: Cracticus torquatus ...
# Trained Cracticus torquatus — AUC: 0.966
#
# Training binary model for species: Hypothymis azurea ...
# Trained Hypothymis azurea — AUC: 0.976
#
# Training binary model for species: Montifringilla nivalis ...
# Trained Montifringilla nivalis — AUC: 0.991
#
# Training binary model for species: Ceratopipra erythrocephala ...
# Trained Ceratopipra erythrocephala — AUC: 0.952
#
# Training binary model for species: Aegithalos glaucogularis ...
# Trained Aegithalos glaucogularis — AUC: 1.000
#
# Training binary model for species: Psilopogon zeylanicus ...
# Trained Psilopogon zeylanicus — AUC: 0.884
#
# Training binary model for species: Micropternus brachyurus ...
# Trained Micropternus brachyurus — AUC: 0.996
#
# Training binary model for species: Cassiculus melanicterus ...
# Trained Cassiculus melanicterus — AUC: 0.994
#
# Training binary model for species: Stomiopera unicolor ...
# Trained Stomiopera unicolor — AUC: 0.963
#
# Training binary model for species: Petroica boodang ...
# Trained Petroica boodang — AUC: 0.980
#
# Training binary model for species: Falco tinnunculus ...
# Trained Falco tinnunculus — AUC: 0.944
#
# Training binary model for species: Zosterops virens ...
# Trained Zosterops virens — AUC: 0.977
#
# Training binary model for species: Bambusicola sonorivox ...
# Trained Bambusicola sonorivox — AUC: 0.982
#
# Training binary model for species: Bolemoreus frenatus ...
# Trained Bolemoreus frenatus — AUC: 0.999
#
# Training binary model for species: Nesoptilotis leucotis ...
# Trained Nesoptilotis leucotis — AUC: 0.983
#
# Training binary model for species: Sturnia pagodarum ...
# Trained Sturnia pagodarum — AUC: 0.979
#
# Training binary model for species: Buteo trizonatus ...
# Trained Buteo trizonatus — AUC: 0.955
#
# Training binary model for species: Sittiparus varius ...
# Trained Sittiparus varius — AUC: 1.000
#
# Training binary model for species: Scleroptila afra ...
# Trained Scleroptila afra — AUC: 0.975
#
# Training binary model for species: Spatula smithii ...
# Trained Spatula smithii — AUC: 0.990
#
# Training binary model for species: Spatula rhynchotis ...
# Trained Spatula rhynchotis — AUC: 0.966
#
# Training binary model for species: Crithagra sulphurata ...
# Trained Crithagra sulphurata — AUC: 0.974
#
# Training binary model for species: Crithagra striolata ...
# Trained Crithagra striolata — AUC: 0.956
#
# Training binary model for species: Pycnonotus plumosus ...
# Trained Pycnonotus plumosus — AUC: 0.988
#
# Training binary model for species: Malurus assimilis ...
# Trained Malurus assimilis — AUC: 0.994
#
# Training binary model for species: Coracias benghalensis ...
# Trained Coracias benghalensis — AUC: 0.981
#
# Training binary model for species: Cyornis tickelliae ...
# Trained Cyornis tickelliae — AUC: 0.950
#
# Training binary model for species: Daphoenositta chrysoptera ...
# Trained Daphoenositta chrysoptera — AUC: 0.953
#
# Training binary model for species: Theristicus branickii ...
# Trained Theristicus branickii — AUC: 1.000
#
# Training binary model for species: Yuhina flavicollis ...
# Trained Yuhina flavicollis — AUC: 0.999
#
# Training binary model for species: Argya affinis ...
# Trained Argya affinis — AUC: 0.985
#
# Training binary model for species: Argya striata ...
# Trained Argya striata — AUC: 0.985
#
# Training binary model for species: Curruca hortensis ...
# Trained Curruca hortensis — AUC: 0.998
#
# Training binary model for species: Neophedina cincta ...
# Trained Neophedina cincta — AUC: 0.822
#
# Training binary model for species: Urile urile ...
# Trained Urile urile — AUC: 1.000
#
# Training binary model for species: Chrysuronia versicolor ...
# Trained Chrysuronia versicolor — AUC: 0.871
#
# Training binary model for species: Riccordia ricordii ...
# Trained Riccordia ricordii — AUC: 1.000
#
# Training binary model for species: Campocolinus coqui ...
# Trained Campocolinus coqui — AUC: 0.931
#
#  Model training completed for all species!
# Total models trained: 285
#              species_name  f1_score       auc
# 0       Aramides saracura  0.154545  0.923607
# 1        Aramides ypecaha  0.408000  0.956446
# 2         Fulica cristata  0.435696  0.981425
# 3  Tetraogallus tibetanus  0.923077  0.999967
# 4       Alectoris barbara  0.608696  0.999840

# %%
#Model sanity check
#Because of AUC being high so wanted to check if everything works well or not

import numpy as np

# 1. Check for overlapping coordinates between train and validation
shared_coords = set(map(tuple, X_train[['latitude', 'longitude']].values)) & set(map(tuple, X_val[['latitude', 'longitude']].values))
print(f" Overlapping coordinates between train & val: {len(shared_coords)}")

# 2. Check class balance for last trained species
print("\nClass distribution for last trained species (target column):")
print(df_train['target'].value_counts())

# 3. Summarize AUC performance across all species
print("\nAUC summary across all species:")
print(results_df["auc"].describe())

# Show top and bottom species by AUC
print("\nTop 5 species by AUC:")
print(results_df.sort_values("auc", ascending=False).head()[["species_name", "auc"]])

print("\nBottom 5 species by AUC:")
print(results_df.sort_values("auc", ascending=True).head()[["species_name", "auc"]])
# Out:
#  Overlapping coordinates between train & val: 0
#
# Class distribution for last trained species (target column):
# target
# 0    120089
# 1        66
# Name: count, dtype: int64
#
# AUC summary across all species:
# count    285.000000
# mean       0.961915
# std        0.042894
# min        0.686008
# 25%        0.949457
# 50%        0.974880
# 75%        0.990757
# max        1.000000
# Name: auc, dtype: float64
#
# Top 5 species by AUC:
#                species_name       auc
# 104      Phrygilus atriceps  1.000000
# 28    Phoebetria palpebrata  0.999988
# 281             Urile urile  0.999981
# 79      Dicrurus forficatus  0.999981
# 202  Pygoscelis antarcticus  0.999972
#
# Bottom 5 species by AUC:
#              species_name       auc
# 75          Artamus minor  0.686008
# 227  Carterornis leucotis  0.746221
# 18      Columba leuconota  0.799274
# 280     Neophedina cincta  0.821988
# 200     Crypturellus soui  0.826660

# %% [markdown]
# Top 10 performing species for validation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top10_species = results_df.sort_values("f1_score", ascending=False).head(10)
print("\nTop 10 Performing Bird Species:")
print(top10_species[["species_name", "f1_score", "auc"]])

plt.figure(figsize=(10, 6))
barplot = sns.barplot(y="species_name", x="f1_score", data=top10_species, palette="crest")
plt.title("Top 10 Performing Bird Species (Validation F1 Score)", fontsize=14, weight="bold")
plt.xlabel("F1 Score", fontsize=12)
plt.ylabel("Species Name", fontsize=12)
plt.xlim(0, 1.05)
plt.tight_layout()
plt.show()
# Out:
# Top 10 Performing Bird Species:
#                    species_name  f1_score       auc
# 104          Phrygilus atriceps  0.977778  1.000000
# 79          Dicrurus forficatus  0.962963  0.999981
# 283          Riccordia ricordii  0.952381  0.999969
# 3        Tetraogallus tibetanus  0.923077  0.999967
# 25          Spheniscus demersus  0.893130  0.999761
# 202      Pygoscelis antarcticus  0.892857  0.999972
# 28        Phoebetria palpebrata  0.888889  0.999988
# 131          Turdus rufitorques  0.871795  0.999908
# 8    Tympanuchus pallidicinctus  0.857143  0.999860
# 275       Theristicus branickii  0.851064  0.999950
# C:\Users\Samriddhi Rawat\AppData\Local\Temp\ipykernel_52984\2775155637.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(y="species_name", x="f1_score", data=top10_species, palette="crest")

# %% [markdown]
# Random location based prediction (need to see how to cross verify)

# %%
new_location = pd.DataFrame([{
    "latitude": 51.75,        # Oxford latitude
    "longitude": -1.25,       # Oxford longitude
    "Tmin_avg": 4.5,          # °C, average winter minimum
    "Tmax_avg": 14.5,         # °C, average summer maximum
    "Prec_avg": 60.0          # mm, average monthly precipitation
}])

new_location = new_location[["latitude", "longitude", "Tmin_avg", "Tmax_avg", "Prec_avg"]]

# Predict probability for each species using trained Random Forest models
species_probs = {}
for sid, model in zip(results_df["species_id"], results_df["model"]):
    try:
        prob = model.predict_proba(new_location)[0, 1]
        species_probs[sid] = prob
    except Exception as e:
        continue  # just in case any model fails, skip

# probability merge with species name
species_probs_df = pd.DataFrame({
    "species_id": list(species_probs.keys()),
    "probability": list(species_probs.values())
})

species_probs_df = species_probs_df.merge(
    results_df[["species_id", "species_name"]],
    on="species_id",
    how="left"
)

#Sort and display top 5 predicted bird species
top5_predictions = species_probs_df.sort_values("probability", ascending=False).head(5)
print("\n Top 5 Predicted Bird Species for Oxford, UK:")
print(top5_predictions[["species_name", "probability"]])

#Plot results for visual clarity
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(9,5))
sns.barplot(
    y="species_name",
    x="probability",
    data=top5_predictions,
    palette="viridis"
)
plt.title("Top 5 Predicted Bird Species for Oxford, UK", fontsize=13, weight="bold")
plt.xlabel("Predicted Probability of Occurrence")
plt.ylabel("Bird Species")
plt.xlim(0, 1)
plt.tight_layout()
plt.show()
# Out:
#  Top 5 Predicted Bird Species for Oxford, UK:
#             species_name  probability
# 257    Falco tinnunculus     0.178581
# 128        Turdus merula     0.145678
# 217  Regulus ignicapilla     0.130359
# 219        Picus viridis     0.129055
# 175         Sylvia borin     0.128963
# C:\Users\Samriddhi Rawat\AppData\Local\Temp\ipykernel_52984\2808713725.py:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# Load and Merge Test Data (birds only)

# %%
print(test_df.shape)
print(test_df.columns.tolist())
test_df.head()
# Out:
# (725335, 10)
# ['latitude', 'longitude', 'taxon_id', 'taxon_name', 'lat_rounded', 'lon_rounded', 'label', 'Tmin_avg', 'Tmax_avg', 'Prec_avg']
#     latitude  longitude  taxon_id                taxon_name  lat_rounded  \
# 0  19.289352 -89.842890      3117  Patagioenas flavirostris     19.28935
# 1  20.777590 -88.534240      3117  Patagioenas flavirostris     20.77759
# 2  21.513868 -86.804565      3117  Patagioenas flavirostris     21.51387
# 4  21.509193 -88.522995      3117  Patagioenas flavirostris     21.50919
# 5  15.438323 -86.370710      3117  Patagioenas flavirostris     15.43832
#
#    lon_rounded  label   Tmin_avg   Tmax_avg    Prec_avg
# 0    -89.84289     20  18.850333  32.721000   91.750000
# 1    -88.53424     20  18.824667  32.724334  103.833333
# 2    -86.80457     20  21.658333  30.716667  100.250000
# 4    -88.52299     20  19.734470  31.497727   73.250000
# 5    -86.37071     20  20.861000  30.976333   95.416667

# %% [markdown]
# Test Prediction

# %%
test_features = test_df[["latitude","longitude","Tmin_avg","Tmax_avg","Prec_avg"]]

proba_matrix = []
species_ids = []

for _, row in results_df.iterrows():
    sp = row["species_id"]
    model = row["model"]
    probs = model.predict_proba(test_features)[:, 1]
    proba_matrix.append(probs)
    species_ids.append(sp)

proba_df = pd.DataFrame(np.array(proba_matrix).T, columns=species_ids)
print("Predicted probabilities for all species on test data.")
# Out:
# Predicted probabilities for all species on test data.

# %%
# Sanity check for train and test data consistency
import numpy as np

# 1. Check for overlapping coordinates between train and test
shared_coords_test = set(map(tuple, X_train[['latitude', 'longitude']].values)) & set(map(tuple, X_test[['latitude', 'longitude']].values))
print(f"Overlapping coordinates between train & test: {len(shared_coords_test)}")

# 2. Basic test feature check
print("\nTest dataset shape:", X_test.shape)
print("Train dataset shape:", X_train.shape)
print("\nAny missing values in test set:", X_test.isnull().sum().sum())

# 3. Ensure test has the same columns as train
train_cols = set(X_train.columns)
test_cols = set(X_test.columns)
if train_cols == test_cols:
    print("\n Test columns match training columns exactly.")
else:
    print("\n Column mismatch detected!")
    print("Columns only in train:", train_cols - test_cols)
    print("Columns only in test:", test_cols - train_cols)

# 4. Compare feature distribution roughly (first few features)
print("\nFeature distribution comparison (mean ± std for first few columns):")
for col in list(X_train.columns)[:5]:
    print(f"{col:<20} Train: {X_train[col].mean():.4f} ± {X_train[col].std():.4f} | Test: {X_test[col].mean():.4f} ± {X_test[col].std():.4f}")

# 5. Quick model sanity run on a small test subset
try:
    sample_preds = model.predict(X_test.head(5))
    print("\nSample predictions on test subset:", sample_preds)
except Exception as e:
    print("\n Prediction sanity check failed:", e)
# Out:
# Overlapping coordinates between train & test: 0
#
# Test dataset shape: (725335, 5)
# Train dataset shape: (120155, 5)
#
# Any missing values in test set: 0
#
#  Test columns match training columns exactly.
#
# Feature distribution comparison (mean ± std for first few columns):
# latitude             Train: 15.5491 ± 32.0203 | Test: 12.8262 ± 29.2414
# longitude            Train: -9.3366 ± 95.9662 | Test: 19.4226 ± 76.1083
# Tmin_avg             Train: -0.0008 ± 1.0007 | Test: 11.1498 ± 10.0132
# Tmax_avg             Train: -0.0008 ± 1.0002 | Test: 23.0859 ± 10.3923
# Prec_avg             Train: -0.0007 ± 0.9982 | Test: 78.5765 ± 60.0666
#
# Sample predictions on test subset: [0 0 0 0 0]

# %% [markdown]
# top predicted species for a random test location

# %%
sample_idx = np.random.randint(0, len(test_df))
sample_location = test_df.iloc[sample_idx]
lat, lon = sample_location["latitude"], sample_location["longitude"]

species_probs = proba_df.iloc[sample_idx].values
top10_idx = np.argsort(species_probs)[::-1][:10]
top10_species = proba_df.columns[top10_idx]
top10_probs = species_probs[top10_idx]

true_species = sample_location["taxon_id"]

print(f"\nTest location #{sample_idx} (Lat: {lat}, Lon: {lon})")
print("Top 10 predicted bird species:")
for rank, (sp, prob) in enumerate(zip(top10_species, top10_probs), 1):
    check = "✅" if sp == true_species else ""
    print(f"{rank}. Species {sp} — Probability {prob:.4f} {check}")

print(f"\nTrue observed species: {true_species}")
# Out:
# Test location #592888 (Lat: 20.69828, Lon: 95.130936)
# Top 10 predicted bird species:
# 1. Species 100 — Probability 0.2117
# 2. Species 34 — Probability 0.1819
# 3. Species 80 — Probability 0.1308
# 4. Species 33 — Probability 0.1151
# 5. Species 154 — Probability 0.0965
# 6. Species 257 — Probability 0.0816
# 7. Species 248 — Probability 0.0665
# 8. Species 16 — Probability 0.0641
# 9. Species 244 — Probability 0.0491
# 10. Species 277 — Probability 0.0332
#
# True observed species: 12910

# %% [markdown]
# plot

# %%
mean_f1 = results_df["f1_score"].mean()
mean_auc = results_df["auc"].mean()
print(f"\nAverage F1 across species: {mean_f1:.3f}")
print(f"Average AUC across species: {mean_auc:.3f}")

plt.figure(figsize=(7,4))
sns.histplot(results_df["f1_score"], bins=20, kde=True)
plt.title("Distribution of Species-wise F1 Scores")
plt.xlabel("F1 Score")
plt.show()
# Out:
# Average F1 across species: 0.314
# Average AUC across species: 0.962
